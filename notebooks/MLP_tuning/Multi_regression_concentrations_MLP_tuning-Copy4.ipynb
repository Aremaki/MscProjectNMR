# %% [markdown]
# # Multi-regression of the metabolites concentrations

# %% [markdown]
# ### Install project packages

# %%
# %%bash
# pip install -e ../.
# Out:
# Obtaining file:///data/ar1220/MscProjectNMR
# Installing collected packages: MscProjectNMR
#   Attempting uninstall: MscProjectNMR
#     Found existing installation: MscProjectNMR 0
#     Uninstalling MscProjectNMR-0:
#       Successfully uninstalled MscProjectNMR-0
#   Running setup.py develop for MscProjectNMR
# Successfully installed MscProjectNMR

# %% [markdown]
# ### Install required python modules

# %%
# %%bash
# pip install -r ../requirements.txt

# %%
tf.__version__
# Out:
# '2.5.0'

# %% [markdown]
# ### Import fucntions

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.cross_decomposition import PLSRegression

import joblib

from tfrecords import write_tfrecords_concentrations, read_tfrecords_concentrations
from models import get_simple_mutli_regressor_mlp, CheckpointCallback

# %% [markdown]
# ---
# # II. Read the tf.Record files

# %% [markdown]
# ## II.3 Large independent dataset (10000 spectra)

# %%
large_train_file_paths = ['../../data/tfrecords/Concentrations_data/Large_sample/train/data_{}.tfrecord'.format(i) 
                        for i in range(32)]
large_val_file_paths = ['../../data/tfrecords/Concentrations_data/Large_sample/validation/data_{}.tfrecord'.format(i) 
                      for i in range(8)]

large_train_dataset = read_tfrecords_concentrations(large_train_file_paths)
large_train_dataset = large_train_dataset.batch(128).shuffle(10000).prefetch(tf.data.experimental.AUTOTUNE)

large_val_dataset = read_tfrecords_concentrations(large_val_file_paths)
large_val_dataset = large_val_dataset.batch(128).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.4 Large correlated dataset (10000 spectra)

# %%
large_corr_train_file_paths = ['../../data/tfrecords/Concentrations_data/Large_correlated/train/data_{}.tfrecord'
                               .format(i) for i in range(32)]
large_corr_val_file_paths = ['../../data/tfrecords/Concentrations_data/Large_correlated/validation/data_{}.tfrecord'
                             .format(i) for i in range(8)]

large_corr_train_dataset = read_tfrecords_concentrations(large_corr_train_file_paths)
large_corr_train_dataset = large_corr_train_dataset.batch(128).shuffle(10000).prefetch(tf.data.experimental.AUTOTUNE)

large_corr_val_dataset = read_tfrecords_concentrations(large_corr_val_file_paths)
large_corr_val_dataset = large_corr_val_dataset.batch(128).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.5 Extra small independent dataset (100 spectra)

# %%
xsmall_train_file_paths = ['../../data/tfrecords/Concentrations_data/Extra_small_sample/train/data_{}.tfrecord'
                           .format(i) for i in range(4)]
xsmall_val_file_paths = ['../../data/tfrecords/Concentrations_data/Extra_small_sample/validation/data_{}.tfrecord'
                         .format(i) for i in range(1)]

xsmall_train_dataset = read_tfrecords_concentrations(xsmall_train_file_paths)
xsmall_train_dataset = xsmall_train_dataset.batch(8).shuffle(100).prefetch(tf.data.experimental.AUTOTUNE)

xsmall_val_dataset = read_tfrecords_concentrations(xsmall_val_file_paths)
xsmall_val_dataset = xsmall_val_dataset.batch(8).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.6 Extra small correlated dataset (100 spectra)

# %%
xsmall_corr_train_file_paths = ['../../data/tfrecords/Concentrations_data/Extra_small_correlated/train/data_{}.tfrecord'
                               .format(i) for i in range(4)]
xsmall_corr_val_file_paths = ['../../data/tfrecords/Concentrations_data/Extra_small_correlated/validation/data_{}.tfrecord'
                             .format(i) for i in range(1)]

xsmall_corr_train_dataset = read_tfrecords_concentrations(xsmall_corr_train_file_paths)
xsmall_corr_train_dataset = xsmall_corr_train_dataset.batch(16).shuffle(1000).prefetch(tf.data.experimental.AUTOTUNE)

xsmall_corr_val_dataset = read_tfrecords_concentrations(xsmall_corr_val_file_paths)
xsmall_corr_val_dataset = xsmall_corr_val_dataset.batch(16).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.7 Test independent dataset (1000 spectra)

# %%
test_file_paths = ['../../data/tfrecords/Concentrations_data/Test_independent/data_{}.tfrecord'
                               .format(i) for i in range(10)]

test_dataset = read_tfrecords_concentrations(test_file_paths)
test_dataset = test_dataset.batch(16).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.8 Test correlated dataset (1000 spectra)

# %%
test_corr_file_paths = ['../../data/tfrecords/Concentrations_data/Test_correlated/data_{}.tfrecord'
                        .format(i) for i in range(10)]

test_corr_dataset = read_tfrecords_concentrations(test_corr_file_paths)
test_corr_dataset = test_corr_dataset.batch(16).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.9 Test abnormal independent dataset (1000 spectra)

# %%
abn_test_file_paths = ['../../data/tfrecords/Concentrations_data/Test_abnormal/data_{}.tfrecord'
                               .format(i) for i in range(10)]

abn_test_dataset = read_tfrecords_concentrations(abn_test_file_paths)
abn_test_dataset = abn_test_dataset.batch(16).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.10 Test correlated dataset (1000 spectra)

# %%
abn_test_corr_file_paths = ['../../data/tfrecords/Concentrations_data/Test_abnormal_corr/data_{}.tfrecord'
                        .format(i) for i in range(10)]

abn_test_corr_dataset = read_tfrecords_concentrations(abn_test_corr_file_paths)
abn_test_corr_dataset = abn_test_corr_dataset.batch(16).prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## II.11 Extract each metabolite from dataset (for independent quantification)

# %%
def extract_metabolite(x, y, metab_index):
    return(x, y[..., metab_index])

xsmall_train_datasets_single = [xsmall_train_dataset.map(lambda x, y: extract_metabolite(x, y, i)) for i in range(48)]
xsmall_val_datasets_single = [xsmall_val_dataset.map(lambda x, y: extract_metabolite(x, y, i)) for i in range(48)]
xsmall_corr_train_datasets_single = [xsmall_corr_train_dataset.map(lambda x, y: extract_metabolite(x, y, i)) 
                                    for i in range(48)]
xsmall_corr_val_datasets_single = [xsmall_corr_val_dataset.map(lambda x, y: extract_metabolite(x, y, i)) 
                                   for i in range(48)]
large_train_datasets_single = [large_train_dataset.map(lambda x, y: extract_metabolite(x, y, i)) for i in range(48)]
large_val_datasets_single = [large_val_dataset.map(lambda x, y: extract_metabolite(x, y, i)) for i in range(48)]
large_corr_train_datasets_single = [large_corr_train_dataset.map(lambda x, y: extract_metabolite(x, y, i))
                                    for i in range(48)]
large_corr_val_datasets_single = [large_corr_val_dataset.map(lambda x, y: extract_metabolite(x, y, i))
                                  for i in range(48)]
test_datasets_single = [test_dataset.map(lambda x, y: extract_metabolite(x, y, i)) for i in range(48)]
test_corr_datasets_single = [test_corr_dataset.map(lambda x, y: extract_metabolite(x, y, i)) for i in range(48)]
abn_test_datasets_single = [abn_test_dataset.map(lambda x, y: extract_metabolite(x, y, i)) for i in range(48)]
abn_test_corr_datasets_single = [abn_test_corr_dataset.map(lambda x, y: extract_metabolite(x, y, i))
                                 for i in range(48)]

# %% [markdown]
# ---
# # III. Define Models

# %% [markdown]
# ## III.3 Large independent dataset

# %% [markdown]
# ### III.3.a Mutli output MLP

# %%
large_multi_mlp = get_simple_mutli_regressor_mlp(input_shape=(10000,), hidden_units=[8192, 1024, 128], num_outputs=48)
large_multi_mlp.summary()
# large_multi_mlp_2048 = get_simple_mutli_regressor_mlp(input_shape=(10000,), hidden_units=[8192, 4096, 2048], 
#                                                       num_outputs=48)
# large_multi_mlp_2048.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10000)]           0
# _________________________________________________________________
# dense (Dense)                (None, 8192)              81928192
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_3 (Dense)              (None, 48)                6192
# =================================================================
# Total params: 90,455,216
# Trainable params: 90,455,216
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## III.4 Large correlated dataset

# %% [markdown]
# ### III.4.a Mutli output MLP

# %%
large_corr_multi_mlp = get_simple_mutli_regressor_mlp(input_shape=(10000,), hidden_units=[8192, 1024, 128], num_outputs=48)
large_corr_multi_mlp.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 10000)]           0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8192)              81928192
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_7 (Dense)              (None, 48)                6192
# =================================================================
# Total params: 90,455,216
# Trainable params: 90,455,216
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## III.5 Exrtra small independent dataset

# %% [markdown]
# ### III.5.a Mutli output MLP

# %%
xsmall_multi_mlp = get_simple_mutli_regressor_mlp(input_shape=(10000,), hidden_units=[8192, 1024, 128], num_outputs=48)
xsmall_multi_mlp.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 10000)]           0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8192)              81928192
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               131200
# _________________________________________________________________
# dense_11 (Dense)             (None, 48)                6192
# =================================================================
# Total params: 90,455,216
# Trainable params: 90,455,216
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## III.6 Extra small correlated dataset

# %% [markdown]
# ### III.6.a Mutli output MLP

# %%
xsmall_corr_multi_mlp = get_simple_mutli_regressor_mlp(input_shape=(10000,), hidden_units=[8192, 1024, 128], num_outputs=48)
xsmall_corr_multi_mlp.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 10000)]           0
# _________________________________________________________________
# dense_12 (Dense)             (None, 8192)              81928192
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              8389632
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               131200
# _________________________________________________________________
# dense_15 (Dense)             (None, 48)                6192
# =================================================================
# Total params: 90,455,216
# Trainable params: 90,455,216
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---
# # IV. Compile models

# %% [markdown]
# ## IV.1 Multi Output MLPs

# %%
xsmall_multi_mlp.compile(optimizer="Adam", loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])
xsmall_corr_multi_mlp.compile(optimizer="Adam", loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])
large_multi_mlp.compile(optimizer="Adam", loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])
large_corr_multi_mlp.compile(optimizer="Adam", loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %% [markdown]
# ---
# # V. Define Callbacks

# %% [markdown]
# ## V.1 Checkpoints

# %%
ckpt_xsmall_multi = CheckpointCallback("../../saved_models/Tuned_multi_mlp/extra_small_multi_8192_1024_128")
ckpt_xsmall_corr_multi = CheckpointCallback("../../saved_models/Tuned_multi_mlp/extra_small_corr_multi_8192_1024_128")
ckpt_large_multi = CheckpointCallback("../../saved_models/Tuned_multi_mlp/large_multi_8192_1024_128")
ckpt_large_corr_multi = CheckpointCallback("../../saved_models/Tuned_multi_mlp/large_corr_multi_8192_1024_128")

# %% [markdown]
# ## V.2 Earlystopping

# %%
earlystopping_100 = tf.keras.callbacks.EarlyStopping(patience=100) #for small dataset
earlystopping_50 = tf.keras.callbacks.EarlyStopping(patience=50) #for large dataset

# %% [markdown]
# ## V.3 Training logs

# %%
logs_xsmall_multi = tf.keras.callbacks.CSVLogger("../../saved_logs/Tuned_multi_mlp/extra_small_multi_8192_1024_128.csv")
logs_xsmall_corr_multi = tf.keras.callbacks.CSVLogger("../../saved_logs/Tuned_multi_mlp/extra_small_corr_multi_8192_1024_128.csv")
logs_large_multi = tf.keras.callbacks.CSVLogger("../../saved_logs/Tuned_multi_mlp/large_multi_8192_1024_128.csv")
logs_large_corr_multi = tf.keras.callbacks.CSVLogger("../../saved_logs/Tuned_multi_mlp/large_corr_multi_8192_1024_128.csv")

# %% [markdown]
# ---
# # VI. Fit models

# %% [markdown]
# ## VI.1 Multi Output MLPs

# %%
xsmall_multi_mlp.fit(xsmall_train_dataset, epochs=1000,
                                          validation_data=xsmall_val_dataset,
                                          callbacks=[ckpt_xsmall_multi, logs_xsmall_multi,
                                                     earlystopping_100])
xsmall_corr_multi_mlp.fit(xsmall_corr_train_dataset, epochs=1000,
                                                    validation_data=xsmall_corr_val_dataset,
                                                    callbacks=[ckpt_xsmall_corr_multi, logs_xsmall_corr_multi,
                                                               earlystopping_100])
large_multi_mlp.fit(large_train_dataset, epochs=1000,
                                          validation_data=large_val_dataset,
                                          callbacks=[ckpt_large_multi, logs_large_multi,
                                                     earlystopping_50])
large_corr_multi_mlp.fit(large_corr_train_dataset, epochs=1000,
                                                    validation_data=large_corr_val_dataset,
                                                    callbacks=[ckpt_large_corr_multi, logs_large_corr_multi,
                                                               earlystopping_50])
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 3s 188ms/step - loss: 2.2360 - root_mean_squared_error: 1.4953 - val_loss: 1.3701 - val_root_mean_squared_error: 1.1705
# Epoch 2/1000
# 10/10 [==============================] - 2s 158ms/step - loss: 1.2112 - root_mean_squared_error: 1.1005 - val_loss: 1.1182 - val_root_mean_squared_error: 1.0574
# Epoch 3/1000
# 10/10 [==============================] - 1s 145ms/step - loss: 1.0170 - root_mean_squared_error: 1.0085 - val_loss: 1.0644 - val_root_mean_squared_error: 1.0317
# Epoch 4/1000
# 10/10 [==============================] - 1s 141ms/step - loss: 0.9661 - root_mean_squared_error: 0.9829 - val_loss: 0.9079 - val_root_mean_squared_error: 0.9528
# Epoch 5/1000
# 10/10 [==============================] - 1s 117ms/step - loss: 0.8939 - root_mean_squared_error: 0.9455 - val_loss: 0.9246 - val_root_mean_squared_error: 0.9616
# Epoch 6/1000
# 10/10 [==============================] - 1s 142ms/step - loss: 0.8655 - root_mean_squared_error: 0.9303 - val_loss: 0.8901 - val_root_mean_squared_error: 0.9435
# Epoch 7/1000
# 10/10 [==============================] - 1s 145ms/step - loss: 0.8353 - root_mean_squared_error: 0.9139 - val_loss: 0.9069 - val_root_mean_squared_error: 0.9523
# Epoch 8/1000
# 10/10 [==============================] - 1s 112ms/step - loss: 0.8279 - root_mean_squared_error: 0.9099 - val_loss: 0.8738 - val_root_mean_squared_error: 0.9348
# Epoch 9/1000
# 10/10 [==============================] - 2s 141ms/step - loss: 0.8283 - root_mean_squared_error: 0.9101 - val_loss: 0.9105 - val_root_mean_squared_error: 0.9542
# Epoch 10/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.7969 - root_mean_squared_error: 0.8927 - val_loss: 0.8586 - val_root_mean_squared_error: 0.9266
# Epoch 11/1000
# 10/10 [==============================] - 2s 137ms/step - loss: 0.7998 - root_mean_squared_error: 0.8943 - val_loss: 0.8765 - val_root_mean_squared_error: 0.9362
# Epoch 12/1000
# 10/10 [==============================] - 1s 119ms/step - loss: 0.7896 - root_mean_squared_error: 0.8886 - val_loss: 0.8497 - val_root_mean_squared_error: 0.9218
# Epoch 13/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.7750 - root_mean_squared_error: 0.8804 - val_loss: 0.8663 - val_root_mean_squared_error: 0.9308
# Epoch 14/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.7758 - root_mean_squared_error: 0.8808 - val_loss: 0.8616 - val_root_mean_squared_error: 0.9282
# Epoch 15/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.7806 - root_mean_squared_error: 0.8835 - val_loss: 0.8584 - val_root_mean_squared_error: 0.9265
# Epoch 16/1000
# 10/10 [==============================] - 1s 117ms/step - loss: 0.7495 - root_mean_squared_error: 0.8657 - val_loss: 0.8700 - val_root_mean_squared_error: 0.9327
# Epoch 17/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.7590 - root_mean_squared_error: 0.8712 - val_loss: 0.8577 - val_root_mean_squared_error: 0.9261
# Epoch 18/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.7378 - root_mean_squared_error: 0.8590 - val_loss: 0.8689 - val_root_mean_squared_error: 0.9321
# Epoch 19/1000
# 10/10 [==============================] - 1s 118ms/step - loss: 0.7391 - root_mean_squared_error: 0.8597 - val_loss: 0.8519 - val_root_mean_squared_error: 0.9230
# Epoch 20/1000
# 10/10 [==============================] - 1s 143ms/step - loss: 0.7309 - root_mean_squared_error: 0.8549 - val_loss: 0.8565 - val_root_mean_squared_error: 0.9255
# Epoch 21/1000
# 10/10 [==============================] - 1s 133ms/step - loss: 0.7103 - root_mean_squared_error: 0.8428 - val_loss: 0.8496 - val_root_mean_squared_error: 0.9218
# Epoch 22/1000
# 10/10 [==============================] - 1s 117ms/step - loss: 0.6961 - root_mean_squared_error: 0.8343 - val_loss: 0.8281 - val_root_mean_squared_error: 0.9100
# Epoch 23/1000
# 10/10 [==============================] - 1s 133ms/step - loss: 0.6990 - root_mean_squared_error: 0.8361 - val_loss: 0.8624 - val_root_mean_squared_error: 0.9287
# Epoch 24/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.6934 - root_mean_squared_error: 0.8327 - val_loss: 0.8579 - val_root_mean_squared_error: 0.9263
# Epoch 25/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.6615 - root_mean_squared_error: 0.8133 - val_loss: 0.8844 - val_root_mean_squared_error: 0.9404
# Epoch 26/1000
# 10/10 [==============================] - 1s 147ms/step - loss: 0.6885 - root_mean_squared_error: 0.8297 - val_loss: 0.8585 - val_root_mean_squared_error: 0.9266
# Epoch 27/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.6789 - root_mean_squared_error: 0.8239 - val_loss: 0.8897 - val_root_mean_squared_error: 0.9433
# Epoch 28/1000
# 10/10 [==============================] - 1s 141ms/step - loss: 0.6730 - root_mean_squared_error: 0.8204 - val_loss: 0.8302 - val_root_mean_squared_error: 0.9112
# Epoch 29/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.6432 - root_mean_squared_error: 0.8020 - val_loss: 0.8402 - val_root_mean_squared_error: 0.9166
# Epoch 30/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.6573 - root_mean_squared_error: 0.8107 - val_loss: 0.8979 - val_root_mean_squared_error: 0.9476
# Epoch 31/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.6671 - root_mean_squared_error: 0.8168 - val_loss: 0.9830 - val_root_mean_squared_error: 0.9914
# Epoch 32/1000
# 10/10 [==============================] - 1s 150ms/step - loss: 0.7100 - root_mean_squared_error: 0.8426 - val_loss: 0.8550 - val_root_mean_squared_error: 0.9247
# Epoch 33/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.6528 - root_mean_squared_error: 0.8080 - val_loss: 0.8566 - val_root_mean_squared_error: 0.9256
# Epoch 34/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.6564 - root_mean_squared_error: 0.8102 - val_loss: 0.9157 - val_root_mean_squared_error: 0.9569
# Epoch 35/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.6409 - root_mean_squared_error: 0.8006 - val_loss: 0.9234 - val_root_mean_squared_error: 0.9609
# Epoch 36/1000
# 10/10 [==============================] - 1s 106ms/step - loss: 0.6036 - root_mean_squared_error: 0.7769 - val_loss: 0.8903 - val_root_mean_squared_error: 0.9436
# Epoch 37/1000
# 10/10 [==============================] - 1s 112ms/step - loss: 0.5981 - root_mean_squared_error: 0.7733 - val_loss: 0.8162 - val_root_mean_squared_error: 0.9034
# Epoch 38/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.5834 - root_mean_squared_error: 0.7638 - val_loss: 0.8248 - val_root_mean_squared_error: 0.9082
# Epoch 39/1000
# 10/10 [==============================] - 1s 131ms/step - loss: 0.6014 - root_mean_squared_error: 0.7755 - val_loss: 0.9058 - val_root_mean_squared_error: 0.9517
# Epoch 40/1000
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5886 - root_mean_squared_error: 0.7672 - val_loss: 0.8626 - val_root_mean_squared_error: 0.9288
# Epoch 41/1000
# 10/10 [==============================] - 1s 140ms/step - loss: 0.5672 - root_mean_squared_error: 0.7531 - val_loss: 0.8411 - val_root_mean_squared_error: 0.9171
# Epoch 42/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.5510 - root_mean_squared_error: 0.7423 - val_loss: 0.8584 - val_root_mean_squared_error: 0.9265
# Epoch 43/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.5605 - root_mean_squared_error: 0.7487 - val_loss: 0.8675 - val_root_mean_squared_error: 0.9314
# Epoch 44/1000
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5542 - root_mean_squared_error: 0.7444 - val_loss: 0.8370 - val_root_mean_squared_error: 0.9149
# Epoch 45/1000
# 10/10 [==============================] - 1s 98ms/step - loss: 0.5441 - root_mean_squared_error: 0.7376 - val_loss: 0.8369 - val_root_mean_squared_error: 0.9148
# Epoch 46/1000
# 10/10 [==============================] - 1s 98ms/step - loss: 0.5436 - root_mean_squared_error: 0.7373 - val_loss: 0.8338 - val_root_mean_squared_error: 0.9131
# Epoch 47/1000
# 10/10 [==============================] - 1s 98ms/step - loss: 0.5533 - root_mean_squared_error: 0.7439 - val_loss: 0.8321 - val_root_mean_squared_error: 0.9122
# Epoch 48/1000
# 10/10 [==============================] - 1s 101ms/step - loss: 0.5575 - root_mean_squared_error: 0.7466 - val_loss: 0.8683 - val_root_mean_squared_error: 0.9318
# Epoch 49/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.5372 - root_mean_squared_error: 0.7329 - val_loss: 0.8376 - val_root_mean_squared_error: 0.9152
# Epoch 50/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.5461 - root_mean_squared_error: 0.7390 - val_loss: 0.8751 - val_root_mean_squared_error: 0.9355
# Epoch 51/1000
# 10/10 [==============================] - 1s 133ms/step - loss: 0.5273 - root_mean_squared_error: 0.7262 - val_loss: 0.8594 - val_root_mean_squared_error: 0.9270
# Epoch 52/1000
# 10/10 [==============================] - 1s 117ms/step - loss: 0.5224 - root_mean_squared_error: 0.7228 - val_loss: 0.8517 - val_root_mean_squared_error: 0.9229
# Epoch 53/1000
# 10/10 [==============================] - 2s 142ms/step - loss: 0.4787 - root_mean_squared_error: 0.6919 - val_loss: 0.8663 - val_root_mean_squared_error: 0.9307
# Epoch 54/1000
# 10/10 [==============================] - 1s 140ms/step - loss: 0.4801 - root_mean_squared_error: 0.6929 - val_loss: 0.8309 - val_root_mean_squared_error: 0.9115
# Epoch 55/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.4666 - root_mean_squared_error: 0.6831 - val_loss: 0.8477 - val_root_mean_squared_error: 0.9207
# Epoch 56/1000
# 10/10 [==============================] - 1s 129ms/step - loss: 0.4912 - root_mean_squared_error: 0.7008 - val_loss: 0.8371 - val_root_mean_squared_error: 0.9149
# Epoch 57/1000
# 10/10 [==============================] - 1s 101ms/step - loss: 0.4637 - root_mean_squared_error: 0.6810 - val_loss: 0.8231 - val_root_mean_squared_error: 0.9072
# Epoch 58/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.4632 - root_mean_squared_error: 0.6806 - val_loss: 0.8702 - val_root_mean_squared_error: 0.9329
# Epoch 59/1000
# 10/10 [==============================] - 1s 132ms/step - loss: 0.4694 - root_mean_squared_error: 0.6851 - val_loss: 0.8425 - val_root_mean_squared_error: 0.9179
# Epoch 60/1000
# 10/10 [==============================] - 1s 141ms/step - loss: 0.4666 - root_mean_squared_error: 0.6831 - val_loss: 0.8561 - val_root_mean_squared_error: 0.9253
# Epoch 61/1000
# 10/10 [==============================] - 1s 147ms/step - loss: 0.4701 - root_mean_squared_error: 0.6856 - val_loss: 0.9144 - val_root_mean_squared_error: 0.9562
# Epoch 62/1000
# 10/10 [==============================] - 1s 131ms/step - loss: 0.4835 - root_mean_squared_error: 0.6953 - val_loss: 0.8555 - val_root_mean_squared_error: 0.9249
# Epoch 63/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.4573 - root_mean_squared_error: 0.6762 - val_loss: 0.8632 - val_root_mean_squared_error: 0.9291
# Epoch 64/1000
# 10/10 [==============================] - 1s 143ms/step - loss: 0.4438 - root_mean_squared_error: 0.6662 - val_loss: 0.8578 - val_root_mean_squared_error: 0.9262
# Epoch 65/1000
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4446 - root_mean_squared_error: 0.6668 - val_loss: 0.9169 - val_root_mean_squared_error: 0.9575
# Epoch 66/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.4475 - root_mean_squared_error: 0.6690 - val_loss: 0.8889 - val_root_mean_squared_error: 0.9428
# Epoch 67/1000
# 10/10 [==============================] - 1s 140ms/step - loss: 0.4400 - root_mean_squared_error: 0.6633 - val_loss: 0.8730 - val_root_mean_squared_error: 0.9343
# Epoch 68/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.4419 - root_mean_squared_error: 0.6647 - val_loss: 0.8687 - val_root_mean_squared_error: 0.9320
# Epoch 69/1000
# 10/10 [==============================] - 1s 118ms/step - loss: 0.4366 - root_mean_squared_error: 0.6608 - val_loss: 0.8541 - val_root_mean_squared_error: 0.9242
# Epoch 70/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.4448 - root_mean_squared_error: 0.6670 - val_loss: 0.9474 - val_root_mean_squared_error: 0.9734
# Epoch 71/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.4840 - root_mean_squared_error: 0.6957 - val_loss: 0.9030 - val_root_mean_squared_error: 0.9503
# Epoch 72/1000
# 10/10 [==============================] - 1s 120ms/step - loss: 0.4374 - root_mean_squared_error: 0.6613 - val_loss: 0.8747 - val_root_mean_squared_error: 0.9352
# Epoch 73/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.4584 - root_mean_squared_error: 0.6771 - val_loss: 0.9462 - val_root_mean_squared_error: 0.9727
# Epoch 74/1000
# 10/10 [==============================] - 1s 144ms/step - loss: 0.4475 - root_mean_squared_error: 0.6690 - val_loss: 0.8704 - val_root_mean_squared_error: 0.9329
# Epoch 75/1000
# 10/10 [==============================] - 1s 143ms/step - loss: 0.4189 - root_mean_squared_error: 0.6472 - val_loss: 0.8509 - val_root_mean_squared_error: 0.9225
# Epoch 76/1000
# 10/10 [==============================] - 1s 142ms/step - loss: 0.4068 - root_mean_squared_error: 0.6378 - val_loss: 0.8813 - val_root_mean_squared_error: 0.9388
# Epoch 77/1000
# 10/10 [==============================] - 1s 118ms/step - loss: 0.4014 - root_mean_squared_error: 0.6336 - val_loss: 0.9083 - val_root_mean_squared_error: 0.9530
# Epoch 78/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.4145 - root_mean_squared_error: 0.6438 - val_loss: 0.8376 - val_root_mean_squared_error: 0.9152
# Epoch 79/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.3834 - root_mean_squared_error: 0.6192 - val_loss: 0.8613 - val_root_mean_squared_error: 0.9280
# Epoch 80/1000
# 10/10 [==============================] - 1s 126ms/step - loss: 0.3557 - root_mean_squared_error: 0.5964 - val_loss: 0.8595 - val_root_mean_squared_error: 0.9271
# Epoch 81/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.3723 - root_mean_squared_error: 0.6102 - val_loss: 0.8749 - val_root_mean_squared_error: 0.9354
# Epoch 82/1000
# 10/10 [==============================] - 1s 143ms/step - loss: 0.3432 - root_mean_squared_error: 0.5858 - val_loss: 0.8519 - val_root_mean_squared_error: 0.9230
# Epoch 83/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.3461 - root_mean_squared_error: 0.5883 - val_loss: 0.8809 - val_root_mean_squared_error: 0.9386
# Epoch 84/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.3153 - root_mean_squared_error: 0.5615 - val_loss: 0.8809 - val_root_mean_squared_error: 0.9386
# Epoch 85/1000
# 10/10 [==============================] - 1s 117ms/step - loss: 0.3452 - root_mean_squared_error: 0.5875 - val_loss: 0.8641 - val_root_mean_squared_error: 0.9296
# Epoch 86/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.3886 - root_mean_squared_error: 0.6234 - val_loss: 0.8385 - val_root_mean_squared_error: 0.9157
# Epoch 87/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.3862 - root_mean_squared_error: 0.6214 - val_loss: 0.8879 - val_root_mean_squared_error: 0.9423
# Epoch 88/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.3461 - root_mean_squared_error: 0.5883 - val_loss: 0.9074 - val_root_mean_squared_error: 0.9526
# Epoch 89/1000
# 10/10 [==============================] - 1s 109ms/step - loss: 0.3538 - root_mean_squared_error: 0.5948 - val_loss: 0.9030 - val_root_mean_squared_error: 0.9503
# Epoch 90/1000
# 10/10 [==============================] - 1s 115ms/step - loss: 0.3670 - root_mean_squared_error: 0.6058 - val_loss: 0.9337 - val_root_mean_squared_error: 0.9663
# Epoch 91/1000
# 10/10 [==============================] - 1s 140ms/step - loss: 0.3900 - root_mean_squared_error: 0.6245 - val_loss: 0.9149 - val_root_mean_squared_error: 0.9565
# Epoch 92/1000
# 10/10 [==============================] - 1s 132ms/step - loss: 0.3697 - root_mean_squared_error: 0.6080 - val_loss: 0.9065 - val_root_mean_squared_error: 0.9521
# Epoch 93/1000
# 10/10 [==============================] - 1s 143ms/step - loss: 0.3278 - root_mean_squared_error: 0.5725 - val_loss: 0.8665 - val_root_mean_squared_error: 0.9309
# Epoch 94/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.3101 - root_mean_squared_error: 0.5569 - val_loss: 0.8648 - val_root_mean_squared_error: 0.9300
# Epoch 95/1000
# 10/10 [==============================] - 1s 113ms/step - loss: 0.3102 - root_mean_squared_error: 0.5570 - val_loss: 0.9007 - val_root_mean_squared_error: 0.9491
# Epoch 96/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.2891 - root_mean_squared_error: 0.5377 - val_loss: 0.8996 - val_root_mean_squared_error: 0.9484
# Epoch 97/1000
# 10/10 [==============================] - 1s 141ms/step - loss: 0.2832 - root_mean_squared_error: 0.5322 - val_loss: 0.9404 - val_root_mean_squared_error: 0.9698
# Epoch 98/1000
# 10/10 [==============================] - 1s 129ms/step - loss: 0.2720 - root_mean_squared_error: 0.5216 - val_loss: 0.8851 - val_root_mean_squared_error: 0.9408
# Epoch 99/1000
# 10/10 [==============================] - 1s 127ms/step - loss: 0.2710 - root_mean_squared_error: 0.5206 - val_loss: 0.8755 - val_root_mean_squared_error: 0.9357
# Epoch 100/1000
# 10/10 [==============================] - 1s 141ms/step - loss: 0.2831 - root_mean_squared_error: 0.5321 - val_loss: 0.9063 - val_root_mean_squared_error: 0.9520
# Epoch 101/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2868 - root_mean_squared_error: 0.5356 - val_loss: 0.8686 - val_root_mean_squared_error: 0.9320
# Epoch 102/1000
# 10/10 [==============================] - 1s 114ms/step - loss: 0.2950 - root_mean_squared_error: 0.5431 - val_loss: 0.8809 - val_root_mean_squared_error: 0.9385
# Epoch 103/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.2589 - root_mean_squared_error: 0.5089 - val_loss: 0.9069 - val_root_mean_squared_error: 0.9523
# Epoch 104/1000
# 10/10 [==============================] - 1s 144ms/step - loss: 0.2591 - root_mean_squared_error: 0.5090 - val_loss: 0.8956 - val_root_mean_squared_error: 0.9464
# Epoch 105/1000
# 10/10 [==============================] - 1s 143ms/step - loss: 0.2346 - root_mean_squared_error: 0.4843 - val_loss: 0.9148 - val_root_mean_squared_error: 0.9565
# Epoch 106/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.2566 - root_mean_squared_error: 0.5066 - val_loss: 0.8833 - val_root_mean_squared_error: 0.9399
# Epoch 107/1000
# 10/10 [==============================] - 1s 115ms/step - loss: 0.2617 - root_mean_squared_error: 0.5115 - val_loss: 0.9183 - val_root_mean_squared_error: 0.9583
# Epoch 108/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.3266 - root_mean_squared_error: 0.5715 - val_loss: 0.9592 - val_root_mean_squared_error: 0.9794
# Epoch 109/1000
# 10/10 [==============================] - 1s 140ms/step - loss: 0.2967 - root_mean_squared_error: 0.5447 - val_loss: 0.8950 - val_root_mean_squared_error: 0.9460
# Epoch 110/1000
# 10/10 [==============================] - 1s 141ms/step - loss: 0.2776 - root_mean_squared_error: 0.5269 - val_loss: 0.9924 - val_root_mean_squared_error: 0.9962
# Epoch 111/1000
# 10/10 [==============================] - 1s 103ms/step - loss: 0.3101 - root_mean_squared_error: 0.5569 - val_loss: 0.9202 - val_root_mean_squared_error: 0.9593
# Epoch 112/1000
# 10/10 [==============================] - 1s 103ms/step - loss: 0.2921 - root_mean_squared_error: 0.5405 - val_loss: 0.8897 - val_root_mean_squared_error: 0.9432
# Epoch 113/1000
# 10/10 [==============================] - 1s 103ms/step - loss: 0.3004 - root_mean_squared_error: 0.5481 - val_loss: 0.8794 - val_root_mean_squared_error: 0.9378
# Epoch 114/1000
# 10/10 [==============================] - 1s 99ms/step - loss: 0.3080 - root_mean_squared_error: 0.5549 - val_loss: 0.9086 - val_root_mean_squared_error: 0.9532
# Epoch 115/1000
# 10/10 [==============================] - 1s 114ms/step - loss: 0.2976 - root_mean_squared_error: 0.5455 - val_loss: 0.8748 - val_root_mean_squared_error: 0.9353
# Epoch 116/1000
# 10/10 [==============================] - 1s 139ms/step - loss: 0.2786 - root_mean_squared_error: 0.5279 - val_loss: 0.9257 - val_root_mean_squared_error: 0.9621
# Epoch 117/1000
# 10/10 [==============================] - 1s 140ms/step - loss: 0.2970 - root_mean_squared_error: 0.5449 - val_loss: 0.9511 - val_root_mean_squared_error: 0.9753
# Epoch 118/1000
# 10/10 [==============================] - 1s 138ms/step - loss: 0.3493 - root_mean_squared_error: 0.5910 - val_loss: 0.9537 - val_root_mean_squared_error: 0.9766
# Epoch 119/1000
# 10/10 [==============================] - 1s 130ms/step - loss: 0.3091 - root_mean_squared_error: 0.5560 - val_loss: 0.9588 - val_root_mean_squared_error: 0.9792
# Epoch 120/1000
# 10/10 [==============================] - 1s 124ms/step - loss: 0.3004 - root_mean_squared_error: 0.5481 - val_loss: 0.9252 - val_root_mean_squared_error: 0.9619
# Epoch 121/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2715 - root_mean_squared_error: 0.5211 - val_loss: 0.8809 - val_root_mean_squared_error: 0.9386
# Epoch 122/1000
# 10/10 [==============================] - 1s 141ms/step - loss: 0.2483 - root_mean_squared_error: 0.4983 - val_loss: 0.9442 - val_root_mean_squared_error: 0.9717
# Epoch 123/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.2872 - root_mean_squared_error: 0.5360 - val_loss: 0.9307 - val_root_mean_squared_error: 0.9647
# Epoch 124/1000
# 10/10 [==============================] - 1s 126ms/step - loss: 0.2791 - root_mean_squared_error: 0.5283 - val_loss: 0.9779 - val_root_mean_squared_error: 0.9889
# Epoch 125/1000
# 10/10 [==============================] - 1s 128ms/step - loss: 0.2493 - root_mean_squared_error: 0.4993 - val_loss: 0.9444 - val_root_mean_squared_error: 0.9718
# Epoch 126/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.2750 - root_mean_squared_error: 0.5244 - val_loss: 0.9045 - val_root_mean_squared_error: 0.9510
# Epoch 127/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2911 - root_mean_squared_error: 0.5395 - val_loss: 0.9079 - val_root_mean_squared_error: 0.9528
# Epoch 128/1000
# 10/10 [==============================] - 1s 105ms/step - loss: 0.2671 - root_mean_squared_error: 0.5168 - val_loss: 0.9275 - val_root_mean_squared_error: 0.9631
# Epoch 129/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2570 - root_mean_squared_error: 0.5069 - val_loss: 0.9402 - val_root_mean_squared_error: 0.9696
# Epoch 130/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2175 - root_mean_squared_error: 0.4664 - val_loss: 0.8636 - val_root_mean_squared_error: 0.9293
# Epoch 131/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2077 - root_mean_squared_error: 0.4557 - val_loss: 0.9165 - val_root_mean_squared_error: 0.9573
# Epoch 132/1000
# 10/10 [==============================] - 1s 137ms/step - loss: 0.2205 - root_mean_squared_error: 0.4696 - val_loss: 0.9647 - val_root_mean_squared_error: 0.9822
# Epoch 133/1000
# 10/10 [==============================] - 1s 108ms/step - loss: 0.2308 - root_mean_squared_error: 0.4804 - val_loss: 0.9390 - val_root_mean_squared_error: 0.9690
# Epoch 134/1000
# 10/10 [==============================] - 1s 135ms/step - loss: 0.2325 - root_mean_squared_error: 0.4822 - val_loss: 0.9804 - val_root_mean_squared_error: 0.9902
# Epoch 135/1000
# 10/10 [==============================] - 1s 136ms/step - loss: 0.2281 - root_mean_squared_error: 0.4776 - val_loss: 0.9913 - val_root_mean_squared_error: 0.9956
# Epoch 136/1000
# 10/10 [==============================] - 1s 134ms/step - loss: 0.2034 - root_mean_squared_error: 0.4509 - val_loss: 0.9479 - val_root_mean_squared_error: 0.9736
# Epoch 137/1000
# 10/10 [==============================] - 1s 133ms/step - loss: 0.1984 - root_mean_squared_error: 0.4455 - val_loss: 0.9446 - val_root_mean_squared_error: 0.9719
# Epoch 1/1000
# 5/5 [==============================] - 2s 226ms/step - loss: 4.4065 - root_mean_squared_error: 2.0992 - val_loss: 3.9861 - val_root_mean_squared_error: 1.9965
# Epoch 2/1000
# 5/5 [==============================] - 1s 145ms/step - loss: 3.0330 - root_mean_squared_error: 1.7415 - val_loss: 3.3170 - val_root_mean_squared_error: 1.8213
# Epoch 3/1000
# 5/5 [==============================] - 1s 147ms/step - loss: 2.7118 - root_mean_squared_error: 1.6468 - val_loss: 3.1735 - val_root_mean_squared_error: 1.7814
# Epoch 4/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 2.5854 - root_mean_squared_error: 1.6079 - val_loss: 3.0912 - val_root_mean_squared_error: 1.7582
# Epoch 5/1000
# 5/5 [==============================] - 1s 154ms/step - loss: 2.4682 - root_mean_squared_error: 1.5710 - val_loss: 3.0202 - val_root_mean_squared_error: 1.7379
# Epoch 6/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 2.3542 - root_mean_squared_error: 1.5344 - val_loss: 2.9886 - val_root_mean_squared_error: 1.7287
# Epoch 7/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 2.2314 - root_mean_squared_error: 1.4938 - val_loss: 2.9506 - val_root_mean_squared_error: 1.7177
# Epoch 8/1000
# 5/5 [==============================] - 1s 143ms/step - loss: 2.2060 - root_mean_squared_error: 1.4853 - val_loss: 2.7575 - val_root_mean_squared_error: 1.6606
# Epoch 9/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 1.8862 - root_mean_squared_error: 1.3734 - val_loss: 2.2667 - val_root_mean_squared_error: 1.5055
# Epoch 10/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 2.5727 - root_mean_squared_error: 1.6040 - val_loss: 3.4665 - val_root_mean_squared_error: 1.8619
# Epoch 11/1000
# 5/5 [==============================] - 1s 148ms/step - loss: 2.3572 - root_mean_squared_error: 1.5353 - val_loss: 2.7047 - val_root_mean_squared_error: 1.6446
# Epoch 12/1000
# 5/5 [==============================] - 1s 139ms/step - loss: 2.0946 - root_mean_squared_error: 1.4473 - val_loss: 2.2765 - val_root_mean_squared_error: 1.5088
# Epoch 13/1000
# 5/5 [==============================] - 1s 111ms/step - loss: 1.7269 - root_mean_squared_error: 1.3141 - val_loss: 1.9802 - val_root_mean_squared_error: 1.4072
# Epoch 14/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 1.6665 - root_mean_squared_error: 1.2909 - val_loss: 1.4863 - val_root_mean_squared_error: 1.2191
# Epoch 15/1000
# 5/5 [==============================] - 1s 118ms/step - loss: 1.5205 - root_mean_squared_error: 1.2331 - val_loss: 1.6319 - val_root_mean_squared_error: 1.2775
# Epoch 16/1000
# 5/5 [==============================] - 1s 137ms/step - loss: 1.3718 - root_mean_squared_error: 1.1713 - val_loss: 1.7485 - val_root_mean_squared_error: 1.3223
# Epoch 17/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 1.1584 - root_mean_squared_error: 1.0763 - val_loss: 1.0976 - val_root_mean_squared_error: 1.0477
# Epoch 18/1000
# 5/5 [==============================] - 1s 159ms/step - loss: 1.0733 - root_mean_squared_error: 1.0360 - val_loss: 1.3455 - val_root_mean_squared_error: 1.1600
# Epoch 19/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 1.2157 - root_mean_squared_error: 1.1026 - val_loss: 1.0477 - val_root_mean_squared_error: 1.0236
# Epoch 20/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 1.0658 - root_mean_squared_error: 1.0324 - val_loss: 1.3121 - val_root_mean_squared_error: 1.1455
# Epoch 21/1000
# 5/5 [==============================] - 1s 147ms/step - loss: 1.0051 - root_mean_squared_error: 1.0026 - val_loss: 1.3318 - val_root_mean_squared_error: 1.1540
# Epoch 22/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 0.9524 - root_mean_squared_error: 0.9759 - val_loss: 1.0039 - val_root_mean_squared_error: 1.0019
# Epoch 23/1000
# 5/5 [==============================] - 1s 181ms/step - loss: 0.8541 - root_mean_squared_error: 0.9242 - val_loss: 0.9290 - val_root_mean_squared_error: 0.9639
# Epoch 24/1000
# 5/5 [==============================] - 1s 144ms/step - loss: 0.8200 - root_mean_squared_error: 0.9055 - val_loss: 0.9293 - val_root_mean_squared_error: 0.9640
# Epoch 25/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.8583 - root_mean_squared_error: 0.9265 - val_loss: 0.9553 - val_root_mean_squared_error: 0.9774
# Epoch 26/1000
# 5/5 [==============================] - 1s 145ms/step - loss: 0.8443 - root_mean_squared_error: 0.9189 - val_loss: 1.1003 - val_root_mean_squared_error: 1.0490
# Epoch 27/1000
# 5/5 [==============================] - 1s 148ms/step - loss: 0.9690 - root_mean_squared_error: 0.9844 - val_loss: 1.3703 - val_root_mean_squared_error: 1.1706
# Epoch 28/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 1.0242 - root_mean_squared_error: 1.0120 - val_loss: 0.9582 - val_root_mean_squared_error: 0.9789
# Epoch 29/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.8224 - root_mean_squared_error: 0.9069 - val_loss: 1.0911 - val_root_mean_squared_error: 1.0446
# Epoch 30/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.7985 - root_mean_squared_error: 0.8936 - val_loss: 0.9250 - val_root_mean_squared_error: 0.9618
# Epoch 31/1000
# 5/5 [==============================] - 1s 131ms/step - loss: 0.7182 - root_mean_squared_error: 0.8475 - val_loss: 0.9493 - val_root_mean_squared_error: 0.9743
# Epoch 32/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.7191 - root_mean_squared_error: 0.8480 - val_loss: 0.9793 - val_root_mean_squared_error: 0.9896
# Epoch 33/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.7105 - root_mean_squared_error: 0.8429 - val_loss: 0.9927 - val_root_mean_squared_error: 0.9964
# Epoch 34/1000
# 5/5 [==============================] - 1s 149ms/step - loss: 0.7118 - root_mean_squared_error: 0.8437 - val_loss: 1.0159 - val_root_mean_squared_error: 1.0079
# Epoch 35/1000
# 5/5 [==============================] - 1s 146ms/step - loss: 0.6843 - root_mean_squared_error: 0.8272 - val_loss: 0.9098 - val_root_mean_squared_error: 0.9538
# Epoch 36/1000
# 5/5 [==============================] - 1s 147ms/step - loss: 0.6689 - root_mean_squared_error: 0.8179 - val_loss: 0.9426 - val_root_mean_squared_error: 0.9709
# Epoch 37/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.6513 - root_mean_squared_error: 0.8071 - val_loss: 0.9017 - val_root_mean_squared_error: 0.9496
# Epoch 38/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.6288 - root_mean_squared_error: 0.7930 - val_loss: 0.8668 - val_root_mean_squared_error: 0.9310
# Epoch 39/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.6199 - root_mean_squared_error: 0.7874 - val_loss: 0.8819 - val_root_mean_squared_error: 0.9391
# Epoch 40/1000
# 5/5 [==============================] - 1s 157ms/step - loss: 0.6062 - root_mean_squared_error: 0.7786 - val_loss: 0.8782 - val_root_mean_squared_error: 0.9371
# Epoch 41/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.6298 - root_mean_squared_error: 0.7936 - val_loss: 0.9029 - val_root_mean_squared_error: 0.9502
# Epoch 42/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 0.6297 - root_mean_squared_error: 0.7936 - val_loss: 0.9241 - val_root_mean_squared_error: 0.9613
# Epoch 43/1000
# 5/5 [==============================] - 1s 156ms/step - loss: 0.6235 - root_mean_squared_error: 0.7896 - val_loss: 0.8893 - val_root_mean_squared_error: 0.9430
# Epoch 44/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.6046 - root_mean_squared_error: 0.7776 - val_loss: 0.8962 - val_root_mean_squared_error: 0.9467
# Epoch 45/1000
# 5/5 [==============================] - 1s 114ms/step - loss: 0.5948 - root_mean_squared_error: 0.7712 - val_loss: 0.9034 - val_root_mean_squared_error: 0.9505
# Epoch 46/1000
# 5/5 [==============================] - 1s 145ms/step - loss: 0.5811 - root_mean_squared_error: 0.7623 - val_loss: 0.8809 - val_root_mean_squared_error: 0.9385
# Epoch 47/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.5748 - root_mean_squared_error: 0.7582 - val_loss: 0.8716 - val_root_mean_squared_error: 0.9336
# Epoch 48/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.6033 - root_mean_squared_error: 0.7767 - val_loss: 0.8809 - val_root_mean_squared_error: 0.9385
# Epoch 49/1000
# 5/5 [==============================] - 1s 159ms/step - loss: 0.5866 - root_mean_squared_error: 0.7659 - val_loss: 0.8997 - val_root_mean_squared_error: 0.9485
# Epoch 50/1000
# 5/5 [==============================] - 1s 161ms/step - loss: 0.5784 - root_mean_squared_error: 0.7606 - val_loss: 0.8586 - val_root_mean_squared_error: 0.9266
# Epoch 51/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.5495 - root_mean_squared_error: 0.7413 - val_loss: 0.8998 - val_root_mean_squared_error: 0.9486
# Epoch 52/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.5582 - root_mean_squared_error: 0.7471 - val_loss: 0.8547 - val_root_mean_squared_error: 0.9245
# Epoch 53/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.5405 - root_mean_squared_error: 0.7352 - val_loss: 0.8962 - val_root_mean_squared_error: 0.9467
# Epoch 54/1000
# 5/5 [==============================] - 1s 133ms/step - loss: 0.5323 - root_mean_squared_error: 0.7296 - val_loss: 0.8479 - val_root_mean_squared_error: 0.9208
# Epoch 55/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.5262 - root_mean_squared_error: 0.7254 - val_loss: 0.8866 - val_root_mean_squared_error: 0.9416
# Epoch 56/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.5268 - root_mean_squared_error: 0.7258 - val_loss: 0.8838 - val_root_mean_squared_error: 0.9401
# Epoch 57/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.5232 - root_mean_squared_error: 0.7233 - val_loss: 0.8409 - val_root_mean_squared_error: 0.9170
# Epoch 58/1000
# 5/5 [==============================] - 1s 141ms/step - loss: 0.4966 - root_mean_squared_error: 0.7047 - val_loss: 0.8356 - val_root_mean_squared_error: 0.9141
# Epoch 59/1000
# 5/5 [==============================] - 1s 146ms/step - loss: 0.5059 - root_mean_squared_error: 0.7113 - val_loss: 0.8578 - val_root_mean_squared_error: 0.9262
# Epoch 60/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.4920 - root_mean_squared_error: 0.7014 - val_loss: 0.8872 - val_root_mean_squared_error: 0.9419
# Epoch 61/1000
# 5/5 [==============================] - 1s 125ms/step - loss: 0.4789 - root_mean_squared_error: 0.6920 - val_loss: 0.8385 - val_root_mean_squared_error: 0.9157
# Epoch 62/1000
# 5/5 [==============================] - 1s 139ms/step - loss: 0.4856 - root_mean_squared_error: 0.6968 - val_loss: 0.8651 - val_root_mean_squared_error: 0.9301
# Epoch 63/1000
# 5/5 [==============================] - 1s 148ms/step - loss: 0.5729 - root_mean_squared_error: 0.7569 - val_loss: 0.9727 - val_root_mean_squared_error: 0.9863
# Epoch 64/1000
# 5/5 [==============================] - 1s 146ms/step - loss: 0.5694 - root_mean_squared_error: 0.7546 - val_loss: 0.9276 - val_root_mean_squared_error: 0.9631
# Epoch 65/1000
# 5/5 [==============================] - 1s 146ms/step - loss: 0.5089 - root_mean_squared_error: 0.7134 - val_loss: 0.8458 - val_root_mean_squared_error: 0.9197
# Epoch 66/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.5758 - root_mean_squared_error: 0.7588 - val_loss: 0.8717 - val_root_mean_squared_error: 0.9336
# Epoch 67/1000
# 5/5 [==============================] - 1s 154ms/step - loss: 0.5129 - root_mean_squared_error: 0.7162 - val_loss: 0.9268 - val_root_mean_squared_error: 0.9627
# Epoch 68/1000
# 5/5 [==============================] - 1s 111ms/step - loss: 0.5280 - root_mean_squared_error: 0.7266 - val_loss: 1.0002 - val_root_mean_squared_error: 1.0001
# Epoch 69/1000
# 5/5 [==============================] - 1s 157ms/step - loss: 0.5242 - root_mean_squared_error: 0.7240 - val_loss: 0.8429 - val_root_mean_squared_error: 0.9181
# Epoch 70/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.5273 - root_mean_squared_error: 0.7262 - val_loss: 0.9114 - val_root_mean_squared_error: 0.9547
# Epoch 71/1000
# 5/5 [==============================] - 1s 148ms/step - loss: 0.5282 - root_mean_squared_error: 0.7267 - val_loss: 1.1285 - val_root_mean_squared_error: 1.0623
# Epoch 72/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.5512 - root_mean_squared_error: 0.7424 - val_loss: 0.9172 - val_root_mean_squared_error: 0.9577
# Epoch 73/1000
# 5/5 [==============================] - 1s 148ms/step - loss: 0.5630 - root_mean_squared_error: 0.7503 - val_loss: 0.8880 - val_root_mean_squared_error: 0.9424
# Epoch 74/1000
# 5/5 [==============================] - 1s 160ms/step - loss: 0.5162 - root_mean_squared_error: 0.7185 - val_loss: 0.9424 - val_root_mean_squared_error: 0.9708
# Epoch 75/1000
# 5/5 [==============================] - 1s 143ms/step - loss: 0.4847 - root_mean_squared_error: 0.6962 - val_loss: 0.9063 - val_root_mean_squared_error: 0.9520
# Epoch 76/1000
# 5/5 [==============================] - 1s 122ms/step - loss: 0.4835 - root_mean_squared_error: 0.6954 - val_loss: 0.9483 - val_root_mean_squared_error: 0.9738
# Epoch 77/1000
# 5/5 [==============================] - 1s 105ms/step - loss: 0.4960 - root_mean_squared_error: 0.7043 - val_loss: 0.8891 - val_root_mean_squared_error: 0.9429
# Epoch 78/1000
# 5/5 [==============================] - 1s 113ms/step - loss: 0.4972 - root_mean_squared_error: 0.7051 - val_loss: 0.8455 - val_root_mean_squared_error: 0.9195
# Epoch 79/1000
# 5/5 [==============================] - 1s 164ms/step - loss: 0.4649 - root_mean_squared_error: 0.6818 - val_loss: 0.9001 - val_root_mean_squared_error: 0.9487
# Epoch 80/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.4875 - root_mean_squared_error: 0.6982 - val_loss: 0.8767 - val_root_mean_squared_error: 0.9363
# Epoch 81/1000
# 5/5 [==============================] - 1s 144ms/step - loss: 0.4266 - root_mean_squared_error: 0.6531 - val_loss: 0.8947 - val_root_mean_squared_error: 0.9459
# Epoch 82/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.4130 - root_mean_squared_error: 0.6427 - val_loss: 0.8297 - val_root_mean_squared_error: 0.9109
# Epoch 83/1000
# 5/5 [==============================] - 1s 159ms/step - loss: 0.4120 - root_mean_squared_error: 0.6419 - val_loss: 0.8630 - val_root_mean_squared_error: 0.9290
# Epoch 84/1000
# 5/5 [==============================] - 1s 161ms/step - loss: 0.4152 - root_mean_squared_error: 0.6443 - val_loss: 0.9037 - val_root_mean_squared_error: 0.9507
# Epoch 85/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 0.3815 - root_mean_squared_error: 0.6176 - val_loss: 0.8184 - val_root_mean_squared_error: 0.9046
# Epoch 86/1000
# 5/5 [==============================] - 1s 140ms/step - loss: 0.3672 - root_mean_squared_error: 0.6060 - val_loss: 0.8139 - val_root_mean_squared_error: 0.9022
# Epoch 87/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 0.3524 - root_mean_squared_error: 0.5936 - val_loss: 0.8372 - val_root_mean_squared_error: 0.9150
# Epoch 88/1000
# 5/5 [==============================] - 1s 142ms/step - loss: 0.3585 - root_mean_squared_error: 0.5988 - val_loss: 0.8346 - val_root_mean_squared_error: 0.9135
# Epoch 89/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.3482 - root_mean_squared_error: 0.5901 - val_loss: 0.8030 - val_root_mean_squared_error: 0.8961
# Epoch 90/1000
# 5/5 [==============================] - 1s 127ms/step - loss: 0.3440 - root_mean_squared_error: 0.5866 - val_loss: 0.8914 - val_root_mean_squared_error: 0.9441
# Epoch 91/1000
# 5/5 [==============================] - 1s 119ms/step - loss: 0.3628 - root_mean_squared_error: 0.6024 - val_loss: 0.8203 - val_root_mean_squared_error: 0.9057
# Epoch 92/1000
# 5/5 [==============================] - 1s 159ms/step - loss: 0.3307 - root_mean_squared_error: 0.5751 - val_loss: 0.8232 - val_root_mean_squared_error: 0.9073
# Epoch 93/1000
# 5/5 [==============================] - 1s 158ms/step - loss: 0.3405 - root_mean_squared_error: 0.5835 - val_loss: 0.8819 - val_root_mean_squared_error: 0.9391
# Epoch 94/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.3434 - root_mean_squared_error: 0.5860 - val_loss: 0.8773 - val_root_mean_squared_error: 0.9367
# Epoch 95/1000
# 5/5 [==============================] - 1s 156ms/step - loss: 0.3839 - root_mean_squared_error: 0.6196 - val_loss: 0.8712 - val_root_mean_squared_error: 0.9334
# Epoch 96/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 0.3857 - root_mean_squared_error: 0.6211 - val_loss: 0.9371 - val_root_mean_squared_error: 0.9680
# Epoch 97/1000
# 5/5 [==============================] - 1s 147ms/step - loss: 0.3901 - root_mean_squared_error: 0.6246 - val_loss: 0.8395 - val_root_mean_squared_error: 0.9163
# Epoch 98/1000
# 5/5 [==============================] - 1s 123ms/step - loss: 0.3520 - root_mean_squared_error: 0.5933 - val_loss: 0.8777 - val_root_mean_squared_error: 0.9369
# Epoch 99/1000
# 5/5 [==============================] - 1s 133ms/step - loss: 0.3769 - root_mean_squared_error: 0.6139 - val_loss: 0.8108 - val_root_mean_squared_error: 0.9004
# Epoch 100/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.3505 - root_mean_squared_error: 0.5920 - val_loss: 0.8677 - val_root_mean_squared_error: 0.9315
# Epoch 101/1000
# 5/5 [==============================] - 1s 149ms/step - loss: 0.3835 - root_mean_squared_error: 0.6193 - val_loss: 1.0153 - val_root_mean_squared_error: 1.0076
# Epoch 102/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.4347 - root_mean_squared_error: 0.6593 - val_loss: 0.9635 - val_root_mean_squared_error: 0.9816
# Epoch 103/1000
# 5/5 [==============================] - 1s 123ms/step - loss: 0.3669 - root_mean_squared_error: 0.6057 - val_loss: 0.8416 - val_root_mean_squared_error: 0.9174
# Epoch 104/1000
# 5/5 [==============================] - 1s 145ms/step - loss: 0.3247 - root_mean_squared_error: 0.5698 - val_loss: 0.8147 - val_root_mean_squared_error: 0.9026
# Epoch 105/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.3203 - root_mean_squared_error: 0.5659 - val_loss: 0.8533 - val_root_mean_squared_error: 0.9237
# Epoch 106/1000
# 5/5 [==============================] - 1s 154ms/step - loss: 0.3281 - root_mean_squared_error: 0.5728 - val_loss: 0.8582 - val_root_mean_squared_error: 0.9264
# Epoch 107/1000
# 5/5 [==============================] - 1s 152ms/step - loss: 0.3261 - root_mean_squared_error: 0.5710 - val_loss: 0.8505 - val_root_mean_squared_error: 0.9222
# Epoch 108/1000
# 5/5 [==============================] - 1s 151ms/step - loss: 0.3340 - root_mean_squared_error: 0.5779 - val_loss: 0.8697 - val_root_mean_squared_error: 0.9326
# Epoch 109/1000
# 5/5 [==============================] - 1s 162ms/step - loss: 0.3087 - root_mean_squared_error: 0.5556 - val_loss: 0.8624 - val_root_mean_squared_error: 0.9287
# Epoch 110/1000
# 5/5 [==============================] - 1s 146ms/step - loss: 0.3464 - root_mean_squared_error: 0.5885 - val_loss: 0.8735 - val_root_mean_squared_error: 0.9346
# Epoch 111/1000
# 5/5 [==============================] - 1s 108ms/step - loss: 0.3362 - root_mean_squared_error: 0.5798 - val_loss: 0.8476 - val_root_mean_squared_error: 0.9206
# Epoch 112/1000
# 5/5 [==============================] - 1s 111ms/step - loss: 0.3167 - root_mean_squared_error: 0.5628 - val_loss: 0.8534 - val_root_mean_squared_error: 0.9238
# Epoch 113/1000
# 5/5 [==============================] - 1s 141ms/step - loss: 0.3046 - root_mean_squared_error: 0.5519 - val_loss: 0.8554 - val_root_mean_squared_error: 0.9249
# Epoch 114/1000
# 5/5 [==============================] - 1s 154ms/step - loss: 0.2990 - root_mean_squared_error: 0.5468 - val_loss: 0.8649 - val_root_mean_squared_error: 0.9300
# Epoch 115/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.3042 - root_mean_squared_error: 0.5516 - val_loss: 0.8591 - val_root_mean_squared_error: 0.9269
# Epoch 116/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.2884 - root_mean_squared_error: 0.5370 - val_loss: 0.8819 - val_root_mean_squared_error: 0.9391
# Epoch 117/1000
# 5/5 [==============================] - 1s 142ms/step - loss: 0.2997 - root_mean_squared_error: 0.5474 - val_loss: 0.8364 - val_root_mean_squared_error: 0.9146
# Epoch 118/1000
# 5/5 [==============================] - 1s 146ms/step - loss: 0.2824 - root_mean_squared_error: 0.5314 - val_loss: 0.8988 - val_root_mean_squared_error: 0.9481
# Epoch 119/1000
# 5/5 [==============================] - 1s 138ms/step - loss: 0.3088 - root_mean_squared_error: 0.5557 - val_loss: 0.9138 - val_root_mean_squared_error: 0.9560
# Epoch 120/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.3122 - root_mean_squared_error: 0.5588 - val_loss: 0.8217 - val_root_mean_squared_error: 0.9065
# Epoch 121/1000
# 5/5 [==============================] - 1s 146ms/step - loss: 0.3014 - root_mean_squared_error: 0.5490 - val_loss: 0.8824 - val_root_mean_squared_error: 0.9393
# Epoch 122/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.2819 - root_mean_squared_error: 0.5309 - val_loss: 0.8350 - val_root_mean_squared_error: 0.9138
# Epoch 123/1000
# 5/5 [==============================] - 1s 155ms/step - loss: 0.2682 - root_mean_squared_error: 0.5179 - val_loss: 0.8594 - val_root_mean_squared_error: 0.9270
# Epoch 124/1000
# 5/5 [==============================] - 1s 141ms/step - loss: 0.2949 - root_mean_squared_error: 0.5430 - val_loss: 0.9180 - val_root_mean_squared_error: 0.9581
# Epoch 125/1000
# 5/5 [==============================] - 1s 111ms/step - loss: 0.3100 - root_mean_squared_error: 0.5568 - val_loss: 0.8306 - val_root_mean_squared_error: 0.9114
# Epoch 126/1000
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3053 - root_mean_squared_error: 0.5525 - val_loss: 0.9554 - val_root_mean_squared_error: 0.9775
# Epoch 127/1000
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3093 - root_mean_squared_error: 0.5561 - val_loss: 0.8474 - val_root_mean_squared_error: 0.9205
# Epoch 128/1000
# 5/5 [==============================] - 1s 110ms/step - loss: 0.3313 - root_mean_squared_error: 0.5756 - val_loss: 0.8646 - val_root_mean_squared_error: 0.9298
# Epoch 129/1000
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3193 - root_mean_squared_error: 0.5650 - val_loss: 0.9583 - val_root_mean_squared_error: 0.9789
# Epoch 130/1000
# 5/5 [==============================] - 1s 108ms/step - loss: 0.3051 - root_mean_squared_error: 0.5524 - val_loss: 0.9770 - val_root_mean_squared_error: 0.9885
# Epoch 131/1000
# 5/5 [==============================] - 1s 106ms/step - loss: 0.3020 - root_mean_squared_error: 0.5495 - val_loss: 0.9449 - val_root_mean_squared_error: 0.9720
# Epoch 132/1000
# 5/5 [==============================] - 1s 111ms/step - loss: 0.2935 - root_mean_squared_error: 0.5417 - val_loss: 0.8597 - val_root_mean_squared_error: 0.9272
# Epoch 133/1000
# 5/5 [==============================] - 1s 109ms/step - loss: 0.2824 - root_mean_squared_error: 0.5314 - val_loss: 0.8511 - val_root_mean_squared_error: 0.9225
# Epoch 134/1000
# 5/5 [==============================] - 1s 111ms/step - loss: 0.2481 - root_mean_squared_error: 0.4981 - val_loss: 0.8938 - val_root_mean_squared_error: 0.9454
# Epoch 135/1000
# 5/5 [==============================] - 1s 145ms/step - loss: 0.2947 - root_mean_squared_error: 0.5429 - val_loss: 0.9121 - val_root_mean_squared_error: 0.9550
# Epoch 136/1000
# 5/5 [==============================] - 1s 153ms/step - loss: 0.2555 - root_mean_squared_error: 0.5055 - val_loss: 0.8569 - val_root_mean_squared_error: 0.9257
# Epoch 137/1000
# 5/5 [==============================] - 1s 147ms/step - loss: 0.2694 - root_mean_squared_error: 0.5190 - val_loss: 0.8800 - val_root_mean_squared_error: 0.9381
# Epoch 138/1000
# 5/5 [==============================] - 1s 150ms/step - loss: 0.3143 - root_mean_squared_error: 0.5606 - val_loss: 1.0462 - val_root_mean_squared_error: 1.0228
# Epoch 139/1000
# ...
# Epoch 334/1000
# 63/63 [==============================] - 14s 216ms/step - loss: 0.1775 - root_mean_squared_error: 0.4213 - val_loss: 0.2263 - val_root_mean_squared_error: 0.4757
# Epoch 335/1000
# 63/63 [==============================] - 14s 204ms/step - loss: 0.1828 - root_mean_squared_error: 0.4275 - val_loss: 0.2161 - val_root_mean_squared_error: 0.4648
# Epoch 336/1000
# 63/63 [==============================] - 13s 190ms/step - loss: 0.1751 - root_mean_squared_error: 0.4185 - val_loss: 0.2455 - val_root_mean_squared_error: 0.4955
# Epoch 337/1000
# 63/63 [==============================] - 14s 207ms/step - loss: 0.1781 - root_mean_squared_error: 0.4220 - val_loss: 0.2279 - val_root_mean_squared_error: 0.4774
# Epoch 338/1000
# 63/63 [==============================] - 12s 175ms/step - loss: 0.1808 - root_mean_squared_error: 0.4252 - val_loss: 0.2417 - val_root_mean_squared_error: 0.4917
# Epoch 339/1000
# 63/63 [==============================] - 12s 179ms/step - loss: 0.1735 - root_mean_squared_error: 0.4166 - val_loss: 0.2431 - val_root_mean_squared_error: 0.4931
# Epoch 340/1000
# 63/63 [==============================] - 12s 179ms/step - loss: 0.1819 - root_mean_squared_error: 0.4265 - val_loss: 0.2272 - val_root_mean_squared_error: 0.4766
# Epoch 341/1000
# 63/63 [==============================] - 11s 161ms/step - loss: 0.1823 - root_mean_squared_error: 0.4269 - val_loss: 0.2225 - val_root_mean_squared_error: 0.4717
# Epoch 342/1000
# 63/63 [==============================] - 11s 166ms/step - loss: 0.1769 - root_mean_squared_error: 0.4206 - val_loss: 0.2253 - val_root_mean_squared_error: 0.4746
# Epoch 343/1000
# 63/63 [==============================] - 10s 152ms/step - loss: 0.1758 - root_mean_squared_error: 0.4192 - val_loss: 0.2275 - val_root_mean_squared_error: 0.4770
# Epoch 344/1000
# 63/63 [==============================] - 10s 154ms/step - loss: 0.1750 - root_mean_squared_error: 0.4183 - val_loss: 0.2501 - val_root_mean_squared_error: 0.5001
# Epoch 345/1000
# 63/63 [==============================] - 12s 173ms/step - loss: 0.1819 - root_mean_squared_error: 0.4265 - val_loss: 0.2373 - val_root_mean_squared_error: 0.4872
# Epoch 1/1000
# 63/63 [==============================] - 12s 156ms/step - loss: 2.8255 - root_mean_squared_error: 1.6809 - val_loss: 2.5966 - val_root_mean_squared_error: 1.6114
# Epoch 2/1000
# 63/63 [==============================] - 12s 176ms/step - loss: 1.1913 - root_mean_squared_error: 1.0915 - val_loss: 0.8788 - val_root_mean_squared_error: 0.9375
# Epoch 3/1000
# 63/63 [==============================] - 12s 174ms/step - loss: 0.7923 - root_mean_squared_error: 0.8901 - val_loss: 0.7405 - val_root_mean_squared_error: 0.8605
# Epoch 4/1000
# 63/63 [==============================] - 11s 169ms/step - loss: 0.7621 - root_mean_squared_error: 0.8730 - val_loss: 0.7691 - val_root_mean_squared_error: 0.8770
# Epoch 5/1000
# 63/63 [==============================] - 10s 154ms/step - loss: 0.7143 - root_mean_squared_error: 0.8452 - val_loss: 0.6581 - val_root_mean_squared_error: 0.8112
# Epoch 6/1000
# 63/63 [==============================] - 11s 172ms/step - loss: 0.6709 - root_mean_squared_error: 0.8191 - val_loss: 0.6217 - val_root_mean_squared_error: 0.7885
# Epoch 7/1000
# 63/63 [==============================] - 11s 158ms/step - loss: 0.6424 - root_mean_squared_error: 0.8015 - val_loss: 0.6251 - val_root_mean_squared_error: 0.7906
# Epoch 8/1000
# 63/63 [==============================] - 11s 162ms/step - loss: 0.6049 - root_mean_squared_error: 0.7778 - val_loss: 0.6010 - val_root_mean_squared_error: 0.7752
# Epoch 9/1000
# 63/63 [==============================] - 11s 169ms/step - loss: 0.6043 - root_mean_squared_error: 0.7774 - val_loss: 0.5379 - val_root_mean_squared_error: 0.7334
# Epoch 10/1000
# 63/63 [==============================] - 11s 165ms/step - loss: 0.5561 - root_mean_squared_error: 0.7457 - val_loss: 0.7171 - val_root_mean_squared_error: 0.8468
# Epoch 11/1000
# 63/63 [==============================] - 11s 169ms/step - loss: 0.6660 - root_mean_squared_error: 0.8161 - val_loss: 0.5324 - val_root_mean_squared_error: 0.7297
# Epoch 12/1000
# 63/63 [==============================] - 9s 138ms/step - loss: 0.5149 - root_mean_squared_error: 0.7175 - val_loss: 0.5339 - val_root_mean_squared_error: 0.7307
# Epoch 13/1000
# 63/63 [==============================] - 12s 176ms/step - loss: 0.5107 - root_mean_squared_error: 0.7146 - val_loss: 0.4669 - val_root_mean_squared_error: 0.6833
# Epoch 14/1000
# 63/63 [==============================] - 10s 143ms/step - loss: 0.5322 - root_mean_squared_error: 0.7295 - val_loss: 0.4605 - val_root_mean_squared_error: 0.6786
# Epoch 15/1000
# 63/63 [==============================] - 11s 172ms/step - loss: 0.5387 - root_mean_squared_error: 0.7340 - val_loss: 0.5774 - val_root_mean_squared_error: 0.7599
# Epoch 16/1000
# 63/63 [==============================] - 12s 175ms/step - loss: 0.4974 - root_mean_squared_error: 0.7053 - val_loss: 0.4591 - val_root_mean_squared_error: 0.6776
# Epoch 17/1000
# 63/63 [==============================] - 10s 143ms/step - loss: 0.4845 - root_mean_squared_error: 0.6960 - val_loss: 0.4981 - val_root_mean_squared_error: 0.7058
# Epoch 18/1000
# 63/63 [==============================] - 12s 177ms/step - loss: 0.4540 - root_mean_squared_error: 0.6738 - val_loss: 0.7530 - val_root_mean_squared_error: 0.8677
# Epoch 19/1000
# 63/63 [==============================] - 10s 155ms/step - loss: 0.4903 - root_mean_squared_error: 0.7002 - val_loss: 0.4669 - val_root_mean_squared_error: 0.6833
# Epoch 20/1000
# 63/63 [==============================] - 11s 170ms/step - loss: 0.4473 - root_mean_squared_error: 0.6688 - val_loss: 0.4104 - val_root_mean_squared_error: 0.6406
# Epoch 21/1000
# 63/63 [==============================] - 11s 173ms/step - loss: 0.4185 - root_mean_squared_error: 0.6469 - val_loss: 0.3886 - val_root_mean_squared_error: 0.6234
# Epoch 22/1000
# 63/63 [==============================] - 12s 176ms/step - loss: 0.4725 - root_mean_squared_error: 0.6874 - val_loss: 0.6112 - val_root_mean_squared_error: 0.7818
# Epoch 23/1000
# 63/63 [==============================] - 10s 150ms/step - loss: 0.4818 - root_mean_squared_error: 0.6941 - val_loss: 0.4319 - val_root_mean_squared_error: 0.6572
# Epoch 24/1000
# 63/63 [==============================] - 10s 150ms/step - loss: 0.4447 - root_mean_squared_error: 0.6669 - val_loss: 0.4044 - val_root_mean_squared_error: 0.6359
# Epoch 25/1000
# 63/63 [==============================] - 10s 146ms/step - loss: 0.3991 - root_mean_squared_error: 0.6318 - val_loss: 0.4777 - val_root_mean_squared_error: 0.6911
# Epoch 26/1000
# 63/63 [==============================] - 11s 170ms/step - loss: 0.4083 - root_mean_squared_error: 0.6390 - val_loss: 0.4082 - val_root_mean_squared_error: 0.6389
# Epoch 27/1000
# 63/63 [==============================] - 12s 173ms/step - loss: 0.3911 - root_mean_squared_error: 0.6254 - val_loss: 0.3831 - val_root_mean_squared_error: 0.6190
# Epoch 28/1000
# 63/63 [==============================] - 11s 159ms/step - loss: 0.4039 - root_mean_squared_error: 0.6356 - val_loss: 0.3500 - val_root_mean_squared_error: 0.5916
# Epoch 29/1000
# 63/63 [==============================] - 10s 153ms/step - loss: 0.4062 - root_mean_squared_error: 0.6373 - val_loss: 0.4357 - val_root_mean_squared_error: 0.6601
# Epoch 30/1000
# 63/63 [==============================] - 11s 168ms/step - loss: 2.6078 - root_mean_squared_error: 1.6149 - val_loss: 2.9916 - val_root_mean_squared_error: 1.7296
# Epoch 31/1000
# 63/63 [==============================] - 11s 169ms/step - loss: 2.9870 - root_mean_squared_error: 1.7283 - val_loss: 2.8174 - val_root_mean_squared_error: 1.6785
# Epoch 32/1000
# 63/63 [==============================] - 12s 175ms/step - loss: 2.8595 - root_mean_squared_error: 1.6910 - val_loss: 2.8141 - val_root_mean_squared_error: 1.6775
# Epoch 33/1000
# 63/63 [==============================] - 13s 200ms/step - loss: 2.8582 - root_mean_squared_error: 1.6906 - val_loss: 2.8146 - val_root_mean_squared_error: 1.6777
# Epoch 34/1000
# 63/63 [==============================] - 14s 208ms/step - loss: 2.8595 - root_mean_squared_error: 1.6910 - val_loss: 2.8122 - val_root_mean_squared_error: 1.6770
# Epoch 35/1000
# 63/63 [==============================] - 14s 209ms/step - loss: 2.8594 - root_mean_squared_error: 1.6910 - val_loss: 2.8118 - val_root_mean_squared_error: 1.6768
# Epoch 36/1000
# 63/63 [==============================] - 13s 205ms/step - loss: 2.8585 - root_mean_squared_error: 1.6907 - val_loss: 2.8126 - val_root_mean_squared_error: 1.6771
# Epoch 37/1000
# 63/63 [==============================] - 14s 210ms/step - loss: 2.8587 - root_mean_squared_error: 1.6908 - val_loss: 2.8121 - val_root_mean_squared_error: 1.6769
# Epoch 38/1000
# 63/63 [==============================] - 14s 212ms/step - loss: 2.8584 - root_mean_squared_error: 1.6907 - val_loss: 2.8205 - val_root_mean_squared_error: 1.6794
# Epoch 39/1000
# 63/63 [==============================] - 13s 199ms/step - loss: 2.8586 - root_mean_squared_error: 1.6908 - val_loss: 2.8123 - val_root_mean_squared_error: 1.6770
# Epoch 40/1000
# 63/63 [==============================] - 13s 198ms/step - loss: 2.8587 - root_mean_squared_error: 1.6908 - val_loss: 2.8162 - val_root_mean_squared_error: 1.6781
# Epoch 41/1000
# 63/63 [==============================] - 13s 195ms/step - loss: 2.8620 - root_mean_squared_error: 1.6918 - val_loss: 2.8110 - val_root_mean_squared_error: 1.6766
# Epoch 42/1000
# 63/63 [==============================] - 14s 216ms/step - loss: 2.8591 - root_mean_squared_error: 1.6909 - val_loss: 2.8187 - val_root_mean_squared_error: 1.6789
# Epoch 43/1000
# 63/63 [==============================] - 14s 213ms/step - loss: 2.8608 - root_mean_squared_error: 1.6914 - val_loss: 2.8153 - val_root_mean_squared_error: 1.6779
# Epoch 44/1000
# 63/63 [==============================] - 14s 211ms/step - loss: 2.8615 - root_mean_squared_error: 1.6916 - val_loss: 2.8130 - val_root_mean_squared_error: 1.6772
# Epoch 45/1000
# 63/63 [==============================] - 13s 201ms/step - loss: 2.8596 - root_mean_squared_error: 1.6910 - val_loss: 2.8140 - val_root_mean_squared_error: 1.6775
# Epoch 46/1000
# 63/63 [==============================] - 14s 206ms/step - loss: 2.8592 - root_mean_squared_error: 1.6909 - val_loss: 2.8143 - val_root_mean_squared_error: 1.6776
# Epoch 47/1000
# 63/63 [==============================] - 13s 191ms/step - loss: 2.8595 - root_mean_squared_error: 1.6910 - val_loss: 2.8126 - val_root_mean_squared_error: 1.6771
# Epoch 48/1000
# 63/63 [==============================] - 13s 199ms/step - loss: 2.8593 - root_mean_squared_error: 1.6910 - val_loss: 2.8115 - val_root_mean_squared_error: 1.6768
# Epoch 49/1000
# 63/63 [==============================] - 13s 191ms/step - loss: 2.8620 - root_mean_squared_error: 1.6917 - val_loss: 2.8142 - val_root_mean_squared_error: 1.6776
# Epoch 50/1000
# 63/63 [==============================] - 14s 211ms/step - loss: 2.8576 - root_mean_squared_error: 1.6905 - val_loss: 2.8155 - val_root_mean_squared_error: 1.6779
# Epoch 51/1000
# 63/63 [==============================] - 13s 196ms/step - loss: 2.8599 - root_mean_squared_error: 1.6911 - val_loss: 2.8125 - val_root_mean_squared_error: 1.6771
# Epoch 52/1000
# 63/63 [==============================] - 14s 215ms/step - loss: 2.8591 - root_mean_squared_error: 1.6909 - val_loss: 2.8137 - val_root_mean_squared_error: 1.6774
# Epoch 53/1000
# 63/63 [==============================] - 13s 192ms/step - loss: 2.8596 - root_mean_squared_error: 1.6910 - val_loss: 2.8162 - val_root_mean_squared_error: 1.6782
# Epoch 54/1000
# 63/63 [==============================] - 13s 199ms/step - loss: 2.8582 - root_mean_squared_error: 1.6906 - val_loss: 2.8131 - val_root_mean_squared_error: 1.6772
# Epoch 55/1000
# 63/63 [==============================] - 14s 207ms/step - loss: 2.8620 - root_mean_squared_error: 1.6917 - val_loss: 2.8142 - val_root_mean_squared_error: 1.6776
# Epoch 56/1000
# 63/63 [==============================] - 13s 203ms/step - loss: 2.8614 - root_mean_squared_error: 1.6916 - val_loss: 2.8149 - val_root_mean_squared_error: 1.6778
# Epoch 57/1000
# 63/63 [==============================] - 13s 199ms/step - loss: 2.8596 - root_mean_squared_error: 1.6910 - val_loss: 2.8169 - val_root_mean_squared_error: 1.6784
# Epoch 58/1000
# 63/63 [==============================] - 14s 213ms/step - loss: 2.8617 - root_mean_squared_error: 1.6917 - val_loss: 2.8198 - val_root_mean_squared_error: 1.6792
# Epoch 59/1000
# 63/63 [==============================] - 13s 200ms/step - loss: 2.8642 - root_mean_squared_error: 1.6924 - val_loss: 2.8187 - val_root_mean_squared_error: 1.6789
# Epoch 60/1000
# 63/63 [==============================] - 14s 208ms/step - loss: 2.8610 - root_mean_squared_error: 1.6915 - val_loss: 2.8129 - val_root_mean_squared_error: 1.6772
# Epoch 61/1000
# 63/63 [==============================] - 14s 204ms/step - loss: 2.8600 - root_mean_squared_error: 1.6912 - val_loss: 2.8158 - val_root_mean_squared_error: 1.6780
# Epoch 62/1000
# 63/63 [==============================] - 13s 196ms/step - loss: 2.8978 - root_mean_squared_error: 1.7023 - val_loss: 2.8153 - val_root_mean_squared_error: 1.6779
# Epoch 63/1000
# 63/63 [==============================] - 13s 200ms/step - loss: 2.8627 - root_mean_squared_error: 1.6919 - val_loss: 2.8156 - val_root_mean_squared_error: 1.6780
# Epoch 64/1000
# 63/63 [==============================] - 13s 199ms/step - loss: 2.8599 - root_mean_squared_error: 1.6911 - val_loss: 2.8155 - val_root_mean_squared_error: 1.6780
# Epoch 65/1000
# 63/63 [==============================] - 13s 197ms/step - loss: 2.8619 - root_mean_squared_error: 1.6917 - val_loss: 2.8155 - val_root_mean_squared_error: 1.6779
# Epoch 66/1000
# 63/63 [==============================] - 14s 207ms/step - loss: 2.8592 - root_mean_squared_error: 1.6909 - val_loss: 2.8190 - val_root_mean_squared_error: 1.6790
# Epoch 67/1000
# 63/63 [==============================] - 14s 214ms/step - loss: 2.9284 - root_mean_squared_error: 1.7112 - val_loss: 2.8217 - val_root_mean_squared_error: 1.6798
# Epoch 68/1000
# 63/63 [==============================] - 13s 195ms/step - loss: 2.8618 - root_mean_squared_error: 1.6917 - val_loss: 2.8141 - val_root_mean_squared_error: 1.6775
# Epoch 69/1000
# 63/63 [==============================] - 13s 193ms/step - loss: 2.8591 - root_mean_squared_error: 1.6909 - val_loss: 2.8171 - val_root_mean_squared_error: 1.6784
# Epoch 70/1000
# 63/63 [==============================] - 13s 196ms/step - loss: 2.8608 - root_mean_squared_error: 1.6914 - val_loss: 2.8136 - val_root_mean_squared_error: 1.6774
# Epoch 71/1000
# 63/63 [==============================] - 14s 208ms/step - loss: 2.8613 - root_mean_squared_error: 1.6915 - val_loss: 2.8164 - val_root_mean_squared_error: 1.6782
# Epoch 72/1000
# 63/63 [==============================] - 14s 215ms/step - loss: 2.8628 - root_mean_squared_error: 1.6920 - val_loss: 2.8144 - val_root_mean_squared_error: 1.6776
# Epoch 73/1000
# 63/63 [==============================] - 14s 213ms/step - loss: 2.8596 - root_mean_squared_error: 1.6910 - val_loss: 2.8245 - val_root_mean_squared_error: 1.6806
# Epoch 74/1000
# 63/63 [==============================] - 14s 205ms/step - loss: 2.8622 - root_mean_squared_error: 1.6918 - val_loss: 2.8140 - val_root_mean_squared_error: 1.6775
# Epoch 75/1000
# 63/63 [==============================] - 14s 212ms/step - loss: 2.8600 - root_mean_squared_error: 1.6912 - val_loss: 2.8137 - val_root_mean_squared_error: 1.6774
# Epoch 76/1000
# 63/63 [==============================] - 13s 199ms/step - loss: 2.8627 - root_mean_squared_error: 1.6919 - val_loss: 2.8169 - val_root_mean_squared_error: 1.6783
# Epoch 77/1000
# 63/63 [==============================] - 14s 212ms/step - loss: 2.8598 - root_mean_squared_error: 1.6911 - val_loss: 2.8170 - val_root_mean_squared_error: 1.6784
# Epoch 78/1000
# 63/63 [==============================] - 14s 215ms/step - loss: 2.8610 - root_mean_squared_error: 1.6915 - val_loss: 2.8166 - val_root_mean_squared_error: 1.6783

# %% [markdown]
# ---
# # VII. Plot the learning curves

# %% [markdown]
# ## VII.1 Multi Output MLPs

# %% [markdown]
# ### VII.1.c Large independent dataset

# %%
#load history from logs
large_multi_history = pd.read_csv("../../saved_logs/Tuned_multi_mlp/large_multi_8192_1024_128.csv")

fig = plt.figure(figsize=(14, 4))

fig.add_subplot(121)
plt.plot(large_multi_history['loss'], label='train', color='C0', linestyle='-')
plt.plot(large_multi_history['val_loss'], label='valid', color='C1', linestyle=':')
plt.title("Loss vs epochs")
plt.xlabel("Epochs")
plt.ylabel("MSE loss")
plt.legend()

fig.add_subplot(122)
plt.plot(large_multi_history['root_mean_squared_error'], label='train', color='C0', linestyle='-')
plt.plot(large_multi_history['val_root_mean_squared_error'], label='valid', color='C1', linestyle=':')
plt.title("RMSE vs epochs")
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.legend()

plt.show()
print(large_multi_mlp.evaluate(large_val_dataset, return_dict=True, verbose=0))
# Out:
# {'loss': 0.23732060194015503, 'root_mean_squared_error': 0.48715561628341675}

# %% [markdown]
# ### VII.1.d Large correlated dataset

# %%
#load history from logs
large_corr_multi_history = pd.read_csv("../../saved_logs/Tuned_multi_mlp/large_corr_multi_8192_1024_128.csv")

fig = plt.figure(figsize=(14, 4))

fig.add_subplot(121)
plt.plot(large_corr_multi_history['loss'], label='train', color='C0', linestyle='-')
plt.plot(large_corr_multi_history['val_loss'], label='valid', color='C1', linestyle=':')
plt.title("Loss vs epochs")
plt.xlabel("Epochs")
plt.ylabel("MSE loss")
plt.legend()

fig.add_subplot(122)
plt.plot(large_corr_multi_history['root_mean_squared_error'], label='train', color='C0', linestyle='-')
plt.plot(large_corr_multi_history['val_root_mean_squared_error'], label='valid', color='C1', linestyle=':')
plt.title("RMSE vs epochs")
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.legend()

plt.show()
print(large_corr_multi_mlp.evaluate(large_corr_val_dataset, return_dict=True, verbose=0))
# Out:
# {'loss': 2.8166134357452393, 'root_mean_squared_error': 1.6782770156860352}

# %% [markdown]
# ### VII.1.e Extra small independent dataset

# %%
#load history from logs
xsmall_multi_history = pd.read_csv("../../saved_logs/Tuned_multi_mlp/extra_small_multi_8192_1024_128.csv")

fig = plt.figure(figsize=(14, 4))

fig.add_subplot(121)
plt.plot(xsmall_multi_history['loss'], label='train', color='C0', linestyle='-')
plt.plot(xsmall_multi_history['val_loss'], label='valid', color='C1', linestyle=':')
plt.title("Loss vs epochs")
plt.xlabel("Epochs")
plt.ylabel("MSE loss")
plt.legend()

fig.add_subplot(122)
plt.plot(xsmall_multi_history['root_mean_squared_error'], label='train', color='C0', linestyle='-')
plt.plot(xsmall_multi_history['val_root_mean_squared_error'], label='valid', color='C1', linestyle=':')
plt.title("RMSE vs epochs")
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.legend()

plt.show()
print(xsmall_multi_mlp.evaluate(xsmall_val_dataset, return_dict=True, verbose=0))
# Out:
# {'loss': 0.9445831179618835, 'root_mean_squared_error': 0.9718966484069824}

# %% [markdown]
# ### VII.1.f Extra small correlated dataset

# %%
#load history from logs
xsmall_corr_multi_history = pd.read_csv("../../saved_logs/Tuned_multi_mlp/extra_small_corr_multi_8192_1024_128.csv")

fig = plt.figure(figsize=(14, 4))

fig.add_subplot(121)
plt.plot(xsmall_corr_multi_history['loss'], label='train', color='C0', linestyle='-')
plt.plot(xsmall_corr_multi_history['val_loss'], label='valid', color='C1', linestyle=':')
plt.title("Loss vs epochs")
plt.xlabel("Epochs")
plt.ylabel("MSE loss")
plt.legend()

fig.add_subplot(122)
plt.plot(xsmall_corr_multi_history['root_mean_squared_error'], label='train', color='C0', linestyle='-')
plt.plot(xsmall_corr_multi_history['val_root_mean_squared_error'], label='valid', color='C1', linestyle=':')
plt.title("RMSE vs epochs")
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.legend()

plt.show()
print(xsmall_corr_multi_mlp.evaluate(xsmall_corr_val_dataset, return_dict=True, verbose=0))
# Out:
# {'loss': 0.8837772607803345, 'root_mean_squared_error': 0.9400942921638489}

# %% [markdown]
# ---
# # VIII. Load saved models

# %% [markdown]
# ## VIII.1 Multi Output MLPs

# %%
xsmall_multi_status = (tf.train.Checkpoint(model=xsmall_multi_mlp)
                      .restore(tf.train.latest_checkpoint('../../saved_models/Tuned_multi_mlp/extra_small_multi_8192_1024_128'))
                      .expect_partial())
xsmall_multi_status.assert_existing_objects_matched()
xsmall_corr_multi_status = (tf.train.Checkpoint(model=xsmall_corr_multi_mlp)
                           .restore(tf.train.latest_checkpoint('../../saved_models/Tuned_multi_mlp/extra_small_corr_multi_8192_1024_128'))
                           .expect_partial())
xsmall_corr_multi_status.assert_existing_objects_matched()
large_multi_status = (tf.train.Checkpoint(model=large_multi_mlp)
                      .restore(tf.train.latest_checkpoint('../../saved_models/Tuned_multi_mlp/large_multi_8192_1024_128'))
                      .expect_partial())
large_multi_status.assert_existing_objects_matched()
large_corr_multi_status = (tf.train.Checkpoint(model=large_corr_multi_mlp)
                           .restore(tf.train.latest_checkpoint('../../saved_models/Tuned_multi_mlp/large_corr_multi_8192_1024_128'))
                           .expect_partial())

# %% [markdown]
# ---
# # XI. Performances:

# %% [markdown]
# ## XI.1. Total RMSE on independent dataset

# %%
inde_rmse_xsmall_multi_mlp = xsmall_multi_mlp.evaluate(test_dataset, return_dict=True,
                                                   verbose=0)['root_mean_squared_error']
inde_rmse_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.evaluate(test_dataset, return_dict=True,
                                                            verbose=0)['root_mean_squared_error']
inde_rmse_large_multi_mlp = large_multi_mlp.evaluate(test_dataset, return_dict=True,
                                                verbose=0)['root_mean_squared_error']
inde_rmse_large_corr_multi_mlp = large_corr_multi_mlp.evaluate(test_dataset, return_dict=True,
                                                          verbose=0)['root_mean_squared_error']

# %%
models = ['MLP multi-output']

training_datasets = ['Extra small independent', 'Extra small correlated',
                     'Large independent', 'Large correlated']

total_rmse_inde = [[inde_rmse_xsmall_multi_mlp, inde_rmse_xsmall_corr_multi_mlp, inde_rmse_large_multi_mlp,
                    inde_rmse_large_corr_multi_mlp]]

# %%
table_total_rmse_inde = pd.DataFrame(total_rmse_inde,
                                     index=pd.Index(models, name='Models'),
                                     columns=pd.Index(training_datasets, name='Training sets'))
table_total_rmse_inde.style.set_caption("Total RMSE evaluated on simulated normal urine with independent metbaolites")
# Out:
# <style  type="text/css" >
# </style><table id="T_e68290c2_e345_11eb_b65b_9bc947eb92c5" ><caption>Total RMSE evaluated on simulated normal urine with independent metbaolites</caption><thead>    <tr>        <th class="index_name level0" >Training sets</th>        <th class="col_heading level0 col0" >Extra small independent</th>        <th class="col_heading level0 col1" >Extra small correlated</th>        <th class="col_heading level0 col2" >Large independent</th>        <th class="col_heading level0 col3" >Large correlated</th>    </tr>    <tr>        <th class="index_name level0" >Models</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e68290c2_e345_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >MLP multi-output</th>
#                         <td id="T_e68290c2_e345_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >0.920291</td>
#                         <td id="T_e68290c2_e345_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >0.909309</td>
#                         <td id="T_e68290c2_e345_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >0.467221</td>
#                         <td id="T_e68290c2_e345_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >0.582808</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## XI.2. Total RMSE on correlated dataset

# %%
corr_rmse_xsmall_multi_mlp = xsmall_multi_mlp.evaluate(test_corr_dataset, return_dict=True,
                                                   verbose=0)['root_mean_squared_error']
corr_rmse_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.evaluate(test_corr_dataset, return_dict=True,
                                                            verbose=0)['root_mean_squared_error']
corr_rmse_large_multi_mlp = large_multi_mlp.evaluate(test_corr_dataset, return_dict=True,
                                                verbose=0)['root_mean_squared_error']
corr_rmse_large_corr_multi_mlp = large_corr_multi_mlp.evaluate(test_corr_dataset, return_dict=True,
                                                          verbose=0)['root_mean_squared_error']

# %%
total_rmse_corr = [[corr_rmse_xsmall_multi_mlp, corr_rmse_xsmall_corr_multi_mlp, corr_rmse_large_multi_mlp, 
                    corr_rmse_large_corr_multi_mlp]]

# %%
table_total_rmse_corr = pd.DataFrame(total_rmse_corr, index=pd.Index(models, name='Models'),
                                     columns=pd.Index(training_datasets, name='Training sets'))
table_total_rmse_corr.style.set_caption("Total RMSE evaluated on simulated normal urine with correlated metbaolites")
# Out:
# <style  type="text/css" >
# </style><table id="T_ebed518c_e345_11eb_b65b_9bc947eb92c5" ><caption>Total RMSE evaluated on simulated normal urine with correlated metbaolites</caption><thead>    <tr>        <th class="index_name level0" >Training sets</th>        <th class="col_heading level0 col0" >Extra small independent</th>        <th class="col_heading level0 col1" >Extra small correlated</th>        <th class="col_heading level0 col2" >Large independent</th>        <th class="col_heading level0 col3" >Large correlated</th>    </tr>    <tr>        <th class="index_name level0" >Models</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ebed518c_e345_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >MLP multi-output</th>
#                         <td id="T_ebed518c_e345_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >1.674156</td>
#                         <td id="T_ebed518c_e345_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >0.932841</td>
#                         <td id="T_ebed518c_e345_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >0.744511</td>
#                         <td id="T_ebed518c_e345_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >0.592148</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## XI.3. Total RMSE on abnormal independent dataset

# %%
abn_inde_rmse_xsmall_multi_mlp = xsmall_multi_mlp.evaluate(abn_test_dataset, return_dict=True,
                                                   verbose=0)['root_mean_squared_error']
abn_inde_rmse_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.evaluate(abn_test_dataset, return_dict=True,
                                                            verbose=0)['root_mean_squared_error']
abn_inde_rmse_large_multi_mlp = large_multi_mlp.evaluate(abn_test_dataset, return_dict=True,
                                                verbose=0)['root_mean_squared_error']
abn_inde_rmse_large_corr_multi_mlp = large_corr_multi_mlp.evaluate(abn_test_dataset, return_dict=True,
                                                          verbose=0)['root_mean_squared_error']

# %%
total_rmse_abn_inde = [[abn_inde_rmse_xsmall_multi_mlp, abn_inde_rmse_xsmall_corr_multi_mlp,
                        abn_inde_rmse_large_multi_mlp, abn_inde_rmse_large_corr_multi_mlp],]

# %%
table_total_rmse_abn_inde = pd.DataFrame(total_rmse_abn_inde, index=pd.Index(models, name='Models'),
                                   columns=pd.Index(training_datasets, name='Training sets'))
table_total_rmse_abn_inde.style.set_caption("Total RMSE evaluated on simulated abnormal urine with independent metbaolites")
# Out:
# <style  type="text/css" >
# </style><table id="T_ef850984_e345_11eb_b65b_9bc947eb92c5" ><caption>Total RMSE evaluated on simulated abnormal urine with independent metbaolites</caption><thead>    <tr>        <th class="index_name level0" >Training sets</th>        <th class="col_heading level0 col0" >Extra small independent</th>        <th class="col_heading level0 col1" >Extra small correlated</th>        <th class="col_heading level0 col2" >Large independent</th>        <th class="col_heading level0 col3" >Large correlated</th>    </tr>    <tr>        <th class="index_name level0" >Models</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef850984_e345_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >MLP multi-output</th>
#                         <td id="T_ef850984_e345_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >7.305627</td>
#                         <td id="T_ef850984_e345_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >6.654608</td>
#                         <td id="T_ef850984_e345_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >4.412842</td>
#                         <td id="T_ef850984_e345_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >4.266936</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## XI.4. Total RMSE on abnromal correlated dataset

# %%
abn_corr_rmse_xsmall_multi_mlp = xsmall_multi_mlp.evaluate(abn_test_corr_dataset, return_dict=True,
                                                   verbose=0)['root_mean_squared_error']
abn_corr_rmse_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.evaluate(abn_test_corr_dataset, return_dict=True,
                                                            verbose=0)['root_mean_squared_error']
abn_corr_rmse_large_multi_mlp = large_multi_mlp.evaluate(abn_test_corr_dataset, return_dict=True,
                                                verbose=0)['root_mean_squared_error']
abn_corr_rmse_large_corr_multi_mlp = large_corr_multi_mlp.evaluate(abn_test_corr_dataset, return_dict=True,
                                                          verbose=0)['root_mean_squared_error']

# %%
total_rmse_abn_corr = [[abn_corr_rmse_xsmall_multi_mlp, abn_corr_rmse_xsmall_corr_multi_mlp,
                        abn_corr_rmse_large_multi_mlp, abn_corr_rmse_large_corr_multi_mlp]]

# %%
table_total_rmse_abn_corr = pd.DataFrame(total_rmse_abn_corr, index=pd.Index(models, name='Models'),
                                         columns=pd.Index(training_datasets, name='Training sets'))
table_total_rmse_abn_corr.style.set_caption("Total RMSE evaluated on simulated abnormal urine with correlated metbaolites")
# Out:
# <style  type="text/css" >
# </style><table id="T_f23ca25e_e345_11eb_b65b_9bc947eb92c5" ><caption>Total RMSE evaluated on simulated abnormal urine with correlated metbaolites</caption><thead>    <tr>        <th class="index_name level0" >Training sets</th>        <th class="col_heading level0 col0" >Extra small independent</th>        <th class="col_heading level0 col1" >Extra small correlated</th>        <th class="col_heading level0 col2" >Large independent</th>        <th class="col_heading level0 col3" >Large correlated</th>    </tr>    <tr>        <th class="index_name level0" >Models</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f23ca25e_e345_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >MLP multi-output</th>
#                         <td id="T_f23ca25e_e345_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >7.167058</td>
#                         <td id="T_f23ca25e_e345_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >6.620726</td>
#                         <td id="T_f23ca25e_e345_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >4.327482</td>
#                         <td id="T_f23ca25e_e345_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >4.100849</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## XI.4. Metabolite wise $R^{2}$ on independent dataset

# %% [markdown]
# ### XI.4.a Import mean concentration data and metabolites

# %%
filename_mean_concentrations = '../data/concentration_data/normal_urine.txt'
mean_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=1, skiprows=1)
sd_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=2, skiprows=1)
filename_concentrations = '../data/concentration_data/Small_sample/Concentrations_Mix1.txt'
metabolites = np.loadtxt(filename_concentrations, delimiter='\t', dtype=str, usecols=0)

# %% [markdown]
# ### XI.4.b Extract ground truth from validation set

# %%
true_val = []
for batch in test_dataset:
    true_val.append(batch[1])
y_val = tf.concat(true_val, axis=0).numpy()

# %% [markdown]
# ### XI.4.c Total sum of squares

# %%
inde_SS_total = tf.reduce_mean(tf.math.square(y_val), axis=0).numpy()
inde_SS_total = pd.Series(inde_SS_total, index=metabolites, name='Total Sum of Squares')

# %% [markdown]
# ### XI.4.c Multi output MLPs

# %%
y_pred_xsmall_multi_mlp = xsmall_multi_mlp.predict(test_dataset)
y_pred_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.predict(test_dataset)
y_pred_large_multi_mlp = large_multi_mlp.predict(test_dataset)
y_pred_large_corr_multi_mlp = large_corr_multi_mlp.predict(test_dataset)


inde_SS_res_xsmall_multi_mlp = tf.reduce_mean(tf.math.square(y_val - y_pred_xsmall_multi_mlp), axis=0).numpy()
inde_R_xsmall_multi_mlp = 1 - inde_SS_res_xsmall_multi_mlp/inde_SS_total
inde_R_xsmall_multi_mlp = pd.Series(inde_R_xsmall_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small set')

inde_SS_res_xsmall_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val - y_pred_xsmall_corr_multi_mlp),
                                                  axis=0).numpy()
inde_R_xsmall_corr_multi_mlp = 1 - inde_SS_res_xsmall_corr_multi_mlp/inde_SS_total
inde_R_xsmall_corr_multi_mlp = pd.Series(inde_R_xsmall_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small correlated set')


inde_SS_res_large_multi_mlp = tf.reduce_mean(tf.math.square(y_val - y_pred_large_multi_mlp), axis=0).numpy()
inde_R_large_multi_mlp = 1 - inde_SS_res_large_multi_mlp/inde_SS_total
inde_R_large_multi_mlp = pd.Series(inde_R_large_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on large set')

inde_SS_res_large_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val - y_pred_large_corr_multi_mlp),
                                                  axis=0).numpy()
inde_R_large_corr_multi_mlp = 1 - inde_SS_res_large_corr_multi_mlp/inde_SS_total
inde_R_large_corr_multi_mlp = pd.Series(inde_R_small_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on large correlated set')

# %% [markdown]
# ### XI.4.i Create the table

# %%
import seaborn as sns
cm = sns.light_palette("green", as_cmap=True)
(summary_table_small.style
  .background_gradient(cmap=cm))

# %%
def color_traget(cell):
    colors = ['lightgreen' if cell[i] > 0 else 'lightcoral' for i in range(8)] + ['white']
    return ['background-color: %s' % color for color in colors]


def font_min_RMSE(cell):
    fonts = ['bold' if (1 - cell[i]) == min(1 - cell[:8]) else '' for i in range (8)] + ['']
    return ['font-weight: %s' % font for font in fonts]

# %%
# target = pd.Series(mean_concentrations/sd_concentrations * 0.3, index=metabolites, name='Target RMSE')

summary_table_xsmall = pd.concat([inde_R_xsmall_multi_mlp,
                                  inde_R_xsmall_corr_multi_mlp,
                                  inde_SS_total], axis=1)
summary_table_large = pd.concat([inde_R_large_multi_mlp,
                                 inde_R_large_corr_multi_mlp,
                                 inde_SS_total], axis=1)

# %%
summary_table_xsmall.style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row2_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row2_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row2_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row3_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row3_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row3_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row4_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row4_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row4_col2,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row4_col3,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row4_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row5_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row5_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row5_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row6_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row6_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row6_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row7_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row7_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row7_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row8_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row8_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row8_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row9_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row9_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row9_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row10_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row10_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row10_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row11_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row11_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row11_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row12_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row12_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row12_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row13_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row13_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row13_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row14_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row14_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row14_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row15_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row15_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row15_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row16_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row16_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row16_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row17_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row17_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row17_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row18_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row18_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row18_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row19_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row19_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row19_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row20_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row20_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row21_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row22_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row22_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row22_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row24_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row25_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row25_col2,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row25_col3,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row25_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row25_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row25_col6,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row27_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row27_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row27_col2,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row27_col3,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row27_col4,#T_e3054152_df20_11eb_b65b_9bc94 ...
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row2_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row3_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row4_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row5_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row6_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row7_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row8_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row9_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row10_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row11_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row12_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row13_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row14_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row15_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row16_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row17_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row18_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row19_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row20_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row21_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row22_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row23_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row24_col0,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row25_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row27_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row28_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row29_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row30_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row31_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row32_col4,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row33_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row35_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row37_col1,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row44_col5,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row47_col1{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }#T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col2,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col3,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col6,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row0_col7,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col2,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col3,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col6,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row1_col7,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row2_col2,#T_e3054152_df20_11eb_b65b_9bc947eb92c5row2_col3,#T_e305415

# %%
summary_table_large.style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_e3054154_df20_11eb_b65b_9bc947eb92c5row0_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row0_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row0_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row1_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row1_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row1_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row2_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row2_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row2_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row3_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row3_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row3_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row4_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row4_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row4_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row4_col6,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row5_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row5_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row5_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row6_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row6_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row6_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row7_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row7_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row7_col5,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row8_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row8_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row8_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row9_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row9_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row9_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row10_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row10_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row10_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row11_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row11_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row11_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row12_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row12_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row12_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row13_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row13_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row13_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row14_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row14_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row14_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row15_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row15_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row15_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row15_col7,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row16_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row16_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row16_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row17_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row17_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row17_col5,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row18_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row18_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row18_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row19_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row19_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row19_col5,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row20_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row20_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row20_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row21_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row21_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row21_col5,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row22_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row22_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row22_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row23_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row23_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row23_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row24_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row24_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row24_col4,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row25_col0,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row25_col1,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row25_col4,#T_e3054154_df20_11eb_b65b_9bc9 ...
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_e3054154_df20_11eb_b65b_9bc947eb92c5row0_col2,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row0_col3,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row0_col6,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row0_col7,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row1_col2,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row1_col3,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row1_col6,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row1_col7,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row2_col2,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row2_col3,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row2_col6,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row2_col7,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row3_col2,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row3_col3,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row3_col6,#T_e3054154_df20_11eb_b65b_9bc947eb92c5row3_col7,#T_e3054154_df20_11eb_b65b_9bc947eb92c5r

# %% [markdown]
# ## XI.5. Metabolite wise RMSE on correlated dataset

# %% [markdown]
# ### XI.5.a Import mean concentration data and metabolites

# %%
filename_mean_concentrations = '../data/concentration_data/normal_urine.txt'
mean_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=1, skiprows=1)
sd_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=2, skiprows=1)
filename_concentrations = '../data/concentration_data/Small_sample/Concentrations_Mix1.txt'
metabolites = np.loadtxt(filename_concentrations, delimiter='\t', dtype=str, usecols=0)

# %% [markdown]
# ### XI.5.b Extract ground truth from validation set

# %%
true_val = []
for batch in test_corr_dataset:
    true_val.append(batch[1])
y_val_corr = tf.concat(true_val, axis=0).numpy()

# %% [markdown]
# ### XI.4.c Total sum of squares

# %%
corr_SS_total = tf.reduce_mean(tf.math.square(y_val_corr), axis=0).numpy()
corr_SS_total = pd.Series(corr_SS_total, index=metabolites, name='Total Sum of Squares')

# %% [markdown]
# ### XI.5.c Multi output MLPs

# %%
y_pred_xsmall_multi_mlp = xsmall_multi_mlp.predict(test_corr_dataset)
y_pred_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.predict(test_corr_dataset)
y_pred_large_multi_mlp = large_multi_mlp.predict(test_corr_dataset)
y_pred_large_corr_multi_mlp = large_corr_multi_mlp.predict(test_corr_dataset)



corr_SS_res_xsmall_multi_mlp = tf.reduce_mean(tf.math.square(y_val_corr - y_pred_xsmall_multi_mlp), axis=0).numpy()
corr_R_xsmall_multi_mlp = 1 - corr_SS_res_xsmall_multi_mlp/corr_SS_total
corr_R_xsmall_multi_mlp = pd.Series(corr_R_xsmall_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small set')

corr_SS_res_xsmall_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val_corr - y_pred_xsmall_corr_multi_mlp),
                                                  axis=0).numpy()
corr_R_xsmall_corr_multi_mlp = 1 - corr_SS_res_xsmall_corr_multi_mlp/corr_SS_total
corr_R_xsmall_corr_multi_mlp = pd.Series(corr_R_xsmall_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small correlated set')

corr_SS_res_large_multi_mlp = tf.reduce_mean(tf.math.square(y_val_corr - y_pred_large_multi_mlp), axis=0).numpy()
corr_R_large_multi_mlp = 1 - corr_SS_res_large_multi_mlp/corr_SS_total
corr_R_large_multi_mlp = pd.Series(corr_R_large_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on large set')

corr_SS_res_large_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val_corr - y_pred_large_corr_multi_mlp),
                                                  axis=0).numpy()
corr_R_large_corr_multi_mlp = 1 - corr_SS_res_large_corr_multi_mlp/corr_SS_total
corr_R_large_corr_multi_mlp = pd.Series(corr_R_large_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on large correlated set')

# %% [markdown]
# ### XI.5.i Create the table

# %%
summary_table_xsmall_corr = pd.concat([corr_R_xsmall_multi_mlp,
                                        corr_R_xsmall_corr_multi_mlp,
                                        corr_SS_total], axis=1)

summary_table_large_corr = pd.concat([corr_R_large_multi_mlp,
                                      corr_R_large_corr_multi_mlp,
                                      corr_SS_total], axis=1)

# %%
overlapped_metabolites = [34, 47, 46, 45, 44, 43, 42, 41, 40]
well_resolved_metabolites = [i for i in range(10)]

# %%
summary_table_xsmall_corr.iloc[overlapped_metabolites].style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col7,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col6,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col7{
#             background-color:  lightcoral;
#             font-weight:  ;
#         }#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col3,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col1{
#             background-color:  lightcoral;
#             font-weight:  bold;
#         }#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row2_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row5_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row6_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row7_col8,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row8_col8{
#             background-color:  white;
#             font-weight:  ;
#         }#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col0,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col4,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col2,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col3{
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col5,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row3_col1,#T_acf2d300_df24_11eb_b65b_9bc947eb92c5row4_col5{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }</style><table id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >R² muti-output MLP trained on extra small set</th>        <th class="col_heading level0 col1" >R² single-output RF trained on extra small set</th>        <th class="col_heading level0 col2" >R² muti-output RF trained on extra small set</th>        <th class="col_heading level0 col3" >R² PLS trained on extra small set</th>        <th class="col_heading level0 col4" >R² muti-output MLP trained on extra small correlated set</th>        <th class="col_heading level0 col5" >R² single-output RF trained on extra small correlated set</th>        <th class="col_heading level0 col6" >R² muti-output RF trained on extra small correlated set</th>        <th class="col_heading level0 col7" >R² PLS trained on extra small correlated set</th>        <th class="col_heading level0 col8" >Total Sum of Squares</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >Phenylacetate</th>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >-0.441151</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >-0.060325</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >-0.089369</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >-0.089369</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col4" class="data row0 col4" >-0.576513</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col5" class="data row0 col5" >-0.052148</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col6" class="data row0 col6" >-0.112321</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col7" class="data row0 col7" >-0.205571</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row0_col8" class="data row0 col8" >1.060587</td>
#             </tr>
#             <tr>
#                         <th id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5level0_row1" class="row_heading level0 row1" >L-serine</th>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col0" class="data row1 col0" >0.205253</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col1" class="data row1 col1" >0.476192</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col2" class="data row1 col2" >-0.098780</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col3" class="data row1 col3" >-0.098780</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col4" class="data row1 col4" >0.291287</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col5" class="data row1 col5" >0.486767</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col6" class="data row1 col6" >-0.208725</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col7" class="data row1 col7" >-0.135729</td>
#                         <td id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5row1_col8" class="data row1 col8" >0.894521</td>
#             </tr>
#             <tr>
#                         <th id="T_acf2d300_df24_11eb_b65b_9bc947eb92c5level0_row2" class="row_head

# %%
summary_table_xsmall_corr.iloc[well_resolved_metabolites].style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col4,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col0,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col4{
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col5,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col1,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col5{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col7,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col2,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col3,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col6,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col7{
#             background-color:  lightcoral;
#             font-weight:  ;
#         }#T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row2_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row3_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row4_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row5_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row6_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row7_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row8_col8,#T_adad2660_df24_11eb_b65b_9bc947eb92c5row9_col8{
#             background-color:  white;
#             font-weight:  ;
#         }</style><table id="T_adad2660_df24_11eb_b65b_9bc947eb92c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >R² muti-output MLP trained on extra small set</th>        <th class="col_heading level0 col1" >R² single-output RF trained on extra small set</th>        <th class="col_heading level0 col2" >R² muti-output RF trained on extra small set</th>        <th class="col_heading level0 col3" >R² PLS trained on extra small set</th>        <th class="col_heading level0 col4" >R² muti-output MLP trained on extra small correlated set</th>        <th class="col_heading level0 col5" >R² single-output RF trained on extra small correlated set</th>        <th class="col_heading level0 col6" >R² muti-output RF trained on extra small correlated set</th>        <th class="col_heading level0 col7" >R² PLS trained on extra small correlated set</th>        <th class="col_heading level0 col8" >Total Sum of Squares</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_adad2660_df24_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >Creatinine</th>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >0.994101</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >0.999360</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >-0.144342</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >-0.144342</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col4" class="data row0 col4" >0.994028</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col5" class="data row0 col5" >0.999328</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col6" class="data row0 col6" >-0.227430</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col7" class="data row0 col7" >-0.856412</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row0_col8" class="data row0 col8" >1.111394</td>
#             </tr>
#             <tr>
#                         <th id="T_adad2660_df24_11eb_b65b_9bc947eb92c5level0_row1" class="row_heading level0 row1" >Hippuric_acid</th>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col0" class="data row1 col0" >0.995155</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col1" class="data row1 col1" >0.999114</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col2" class="data row1 col2" >-0.080311</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col3" class="data row1 col3" >-0.080311</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col4" class="data row1 col4" >0.994248</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col5" class="data row1 col5" >0.999095</td>
#                         <td id="T_adad2660_df24_11eb_b65b_9bc947eb92c5row1_col6" class="data row1 col6" >-0.075067</td>

# %%
summary_table_large_corr.iloc[overlapped_metabolites].style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col5{
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col4,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col7,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col0,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col2,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col3,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col6,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col7{
#             background-color:  lightcoral;
#             font-weight:  ;
#         }#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col1,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col5,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col1{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row3_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row4_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row5_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row6_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row7_col8,#T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row8_col8{
#             background-color:  white;
#             font-weight:  ;
#         }</style><table id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >R² muti-output MLP trained on large set</th>        <th class="col_heading level0 col1" >R² single-output RF trained on large set</th>        <th class="col_heading level0 col2" >R² muti-output RF trained on large set</th>        <th class="col_heading level0 col3" >R² PLS trained on large set</th>        <th class="col_heading level0 col4" >R² muti-output MLP trained on large correlated set</th>        <th class="col_heading level0 col5" >R² single-output RF trained on large correlated set</th>        <th class="col_heading level0 col6" >R² muti-output RF trained on large correlated set</th>        <th class="col_heading level0 col7" >R² PLS trained on large correlated set</th>        <th class="col_heading level0 col8" >Total Sum of Squares</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >Phenylacetate</th>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >0.012258</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >-0.000479</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >-0.119392</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >-0.940233</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col4" class="data row0 col4" >0.203998</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col5" class="data row0 col5" >0.293778</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col6" class="data row0 col6" >-0.119598</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col7" class="data row0 col7" >-0.019091</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row0_col8" class="data row0 col8" >1.060587</td>
#             </tr>
#             <tr>
#                         <th id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5level0_row1" class="row_heading level0 row1" >L-serine</th>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col0" class="data row1 col0" >0.954490</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col1" class="data row1 col1" >0.973314</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col2" class="data row1 col2" >-0.129225</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col3" class="data row1 col3" >-0.841177</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col4" class="data row1 col4" >0.968061</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col5" class="data row1 col5" >0.959704</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col6" class="data row1 col6" >-0.113795</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col7" class="data row1 col7" >-0.150267</td>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row1_col8" class="data row1 col8" >0.894521</td>
#             </tr>
#             <tr>
#                         <th id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5level0_row2" class="row_heading level0 row2" >n-butyrate</th>
#                         <td id="T_c9a70ade_df24_11eb_b65b_9bc947eb92c5row2_col0" class="data row2 col0

# %%
summary_table_large_corr.iloc[well_resolved_metabolites].style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col0,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col4,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col5{
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col7,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col2,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col3,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col6,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col7{
#             background-color:  lightcoral;
#             font-weight:  ;
#         }#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col1,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col5,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col1{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row2_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row3_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row4_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row5_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row6_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row7_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row8_col8,#T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row9_col8{
#             background-color:  white;
#             font-weight:  ;
#         }</style><table id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >R² muti-output MLP trained on large set</th>        <th class="col_heading level0 col1" >R² single-output RF trained on large set</th>        <th class="col_heading level0 col2" >R² muti-output RF trained on large set</th>        <th class="col_heading level0 col3" >R² PLS trained on large set</th>        <th class="col_heading level0 col4" >R² muti-output MLP trained on large correlated set</th>        <th class="col_heading level0 col5" >R² single-output RF trained on large correlated set</th>        <th class="col_heading level0 col6" >R² muti-output RF trained on large correlated set</th>        <th class="col_heading level0 col7" >R² PLS trained on large correlated set</th>        <th class="col_heading level0 col8" >Total Sum of Squares</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >Creatinine</th>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >0.988926</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >0.999779</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >-0.308826</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >-1.120593</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col4" class="data row0 col4" >0.998933</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col5" class="data row0 col5" >0.999928</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col6" class="data row0 col6" >-0.378719</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col7" class="data row0 col7" >-1.017420</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row0_col8" class="data row0 col8" >1.111394</td>
#             </tr>
#             <tr>
#                         <th id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5level0_row1" class="row_heading level0 row1" >Hippuric_acid</th>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col0" class="data row1 col0" >0.991694</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col1" class="data row1 col1" >0.999881</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col2" class="data row1 col2" >-0.093649</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col3" class="data row1 col3" >-0.938262</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col4" class="data row1 col4" >0.990588</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col5" class="data row1 col5" >0.999902</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb92c5row1_col6" class="data row1 col6" >-0.152737</td>
#                         <td id="T_a7539cca_df2b_11eb_b65b_9bc947eb

# %% [markdown]
# ## XI.6. Metabolite wise RMSE on abnormal independent dataset

# %% [markdown]
# ### XI.6.a Import mean concentration data and metabolites

# %%
filename_mean_concentrations = '../data/concentration_data/normal_urine.txt'
mean_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=1, skiprows=1)
sd_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=2, skiprows=1)
filename_concentrations = '../data/concentration_data/Small_sample/Concentrations_Mix1.txt'
metabolites = np.loadtxt(filename_concentrations, delimiter='\t', dtype=str, usecols=0)

# %% [markdown]
# ### XI.6.b Extract ground truth from validation set

# %%
true_val = []
for batch in abn_test_dataset:
    true_val.append(batch[1])
y_val_abn = tf.concat(true_val, axis=0).numpy()

# %% [markdown]
# ### XI.4.c Total sum of squares

# %%
abn_inde_SS_total = tf.reduce_mean(tf.math.square(y_val_abn), axis=0).numpy()
abn_inde_SS_total = pd.Series(abn_inde_SS_total, index=metabolites, name='Total Sum of Squares')

# %% [markdown]
# ### XI.6.c Multi output MLPs

# %%
y_pred_xsmall_multi_mlp = xsmall_multi_mlp.predict(abn_test_dataset)
y_pred_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.predict(abn_test_dataset)
y_pred_large_multi_mlp = large_multi_mlp.predict(abn_test_dataset)
y_pred_large_corr_multi_mlp = large_corr_multi_mlp.predict(abn_test_dataset)


abn_inde_SS_res_xsmall_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn - y_pred_xsmall_multi_mlp), axis=0).numpy()
abn_inde_R_xsmall_multi_mlp = 1 - abn_inde_SS_res_xsmall_multi_mlp/abn_inde_SS_total
abn_inde_R_xsmall_multi_mlp = pd.Series(abn_inde_R_xsmall_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small set')

abn_inde_SS_res_xsmall_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn - y_pred_xsmall_corr_multi_mlp),
                                                  axis=0).numpy()
abn_inde_R_xsmall_corr_multi_mlp = 1 - abn_inde_SS_res_xsmall_corr_multi_mlp/abn_inde_SS_total
abn_inde_R_xsmall_corr_multi_mlp = pd.Series(abn_inde_R_xsmall_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small correlated set')

abn_inde_SS_res_large_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn - y_pred_large_multi_mlp), axis=0).numpy()
abn_inde_R_large_multi_mlp = 1 - abn_inde_SS_res_large_multi_mlp/abn_inde_SS_total
abn_inde_R_large_multi_mlp = pd.Series(abn_inde_R_large_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on large set')

abn_inde_SS_res_large_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn - y_pred_large_corr_multi_mlp),
                                                  axis=0).numpy()
abn_inde_R_large_corr_multi_mlp = 1 - abn_inde_SS_res_large_corr_multi_mlp/abn_inde_SS_total
abn_inde_R_large_corr_multi_mlp = pd.Series(abn_inde_R_large_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on large correlated set')

# %% [markdown]
# ### XI.6.i Create the table

# %%
summary_table_abn_xsmall = pd.concat([abn_inde_R_xsmall_multi_mlp,
                                      abn_inde_R_xsmall_corr_multi_mlp,
                                      abn_inde_SS_total], axis=1)
summary_table_abn_large = pd.concat([abn_inde_R_large_multi_mlp,
                                     abn_inde_R_large_corr_multi_mlp,
                                     abn_inde_SS_total], axis=1)

# %%
summary_table_abn_xsmall.style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col2,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col3,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col7,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row1_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row1_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row1_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row2_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row2_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row2_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row2_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row2_col7,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row3_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row3_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col2,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col3,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row5_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row5_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row5_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row7_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row7_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row7_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row11_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row11_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row11_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row11_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row11_col7,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row12_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row12_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row12_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row13_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row14_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row14_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row15_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row15_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row15_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row18_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col2,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col3,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col7,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row22_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row22_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row22_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col2,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col3,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col7,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row27_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row27_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row30_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row32_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row32_col2,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row32_col3,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row32_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row32_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col2,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col3,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row37_col2,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row37_col3,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row37_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row37_col6,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row40_col0,#T_6fbc5c48_df21_11eb_b65b_9b ...
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row1_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row2_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row3_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row5_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row6_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row7_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row10_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row11_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row12_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row13_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row14_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row15_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row16_col0,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row17_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row18_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row20_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row22_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row26_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row27_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row28_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row30_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row32_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row35_col5,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row37_col1,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row40_col4,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row44_col5{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row0_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row1_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row2_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row3_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row4_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row5_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row6_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row7_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row8_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row9_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row10_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row11_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row12_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row13_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row14_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row15_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row16_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row17_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row18_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row19_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row20_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row21_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row22_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row23_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row24_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row25_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row26_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row27_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row28_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row29_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row30_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row31_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row32_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row33_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row34_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row35_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row36_col8,#T_6fbc5c48_df21_11eb_b65b_9bc947eb92c5row37_col8,#T_6f

# %%
summary_table_abn_large.iloc[overlapped_metabolites].style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col1{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col7{
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col7,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col7,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col7,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col7,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col7,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col7,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col2,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col7,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col0,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col3,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col4,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col6,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col7{
#             background-color:  lightcoral;
#             font-weight:  ;
#         }#T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row4_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row5_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row6_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col8,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row8_col8{
#             background-color:  white;
#             font-weight:  ;
#         }#T_d5507348_df24_11eb_b65b_9bc947eb92c5row2_col5,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row3_col1,#T_d5507348_df24_11eb_b65b_9bc947eb92c5row7_col2{
#             background-color:  lightcoral;
#             font-weight:  bold;
#         }</style><table id="T_d5507348_df24_11eb_b65b_9bc947eb92c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >R² muti-output MLP trained on large set</th>        <th class="col_heading level0 col1" >R² single-output RF trained on large set</th>        <th class="col_heading level0 col2" >R² muti-output RF trained on large set</th>        <th class="col_heading level0 col3" >R² PLS trained on large set</th>        <th class="col_heading level0 col4" >R² muti-output MLP trained on large correlated set</th>        <th class="col_heading level0 col5" >R² single-output RF trained on large correlated set</th>        <th class="col_heading level0 col6" >R² muti-output RF trained on large correlated set</th>        <th class="col_heading level0 col7" >R² PLS trained on large correlated set</th>        <th class="col_heading level0 col8" >Total Sum of Squares</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d5507348_df24_11eb_b65b_9bc947eb92c5level0_row0" class="row_heading level0 row0" >Phenylacetate</th>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col0" class="data row0 col0" >0.003826</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col1" class="data row0 col1" >0.000237</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col2" class="data row0 col2" >-0.133229</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col3" class="data row0 col3" >-1.436283</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col4" class="data row0 col4" >-0.592977</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col5" class="data row0 col5" >-0.266896</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col6" class="data row0 col6" >-0.098851</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col7" class="data row0 col7" >-2.377705</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row0_col8" class="data row0 col8" >1.004514</td>
#             </tr>
#             <tr>
#                         <th id="T_d5507348_df24_11eb_b65b_9bc947eb92c5level0_row1" class="row_heading level0 row1" >L-serine</th>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col0" class="data row1 col0" >0.785331</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col1" class="data row1 col1" >0.989956</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col2" class="data row1 col2" >-0.111495</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col3" class="data row1 col3" >-0.849027</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col4" class="data row1 col4" >0.838941</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col5" class="data row1 col5" >0.889071</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col6" class="data row1 col6" >-0.078337</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col7" class="data row1 col7" >-10.531075</td>
#                         <td id="T_d5507348_df24_11eb_b65b_9bc947eb92c5row1_col8" class="data row1 col8" >0.915599</td>
#             </tr>
#             <tr>
#                         <th id="T_d5507348_df24_11eb_b65b_9bc947eb92c5level0_row2" class="row_heading level0 row2" >n-butyrate</th>

# %% [markdown]
# ## XI.7. Metabolite wise RMSE on abnormal correlated dataset

# %% [markdown]
# ### XI.7.a Import mean concentration data and metabolites

# %%
filename_mean_concentrations = '../data/concentration_data/normal_urine.txt'
mean_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=1, skiprows=1)
sd_concentrations = np.loadtxt(filename_mean_concentrations, delimiter='\t', dtype=float, usecols=2, skiprows=1)
filename_concentrations = '../data/concentration_data/Small_sample/Concentrations_Mix1.txt'
metabolites = np.loadtxt(filename_concentrations, delimiter='\t', dtype=str, usecols=0)

# %% [markdown]
# ### XI.7.b Extract ground truth from validation set

# %%
true_val = []
for batch in abn_test_corr_dataset:
    true_val.append(batch[1])
y_val_abn_corr = tf.concat(true_val, axis=0).numpy()

# %% [markdown]
# ### XI.4.c Total sum of squares

# %%
abn_corr_SS_total = tf.reduce_mean(tf.math.square(y_val_abn_corr), axis=0).numpy()
abn_corr_SS_total = pd.Series(abn_corr_SS_total, index=metabolites, name='Total Sum of Squares')

# %% [markdown]
# ### XI.7.c Multi output MLPs

# %%
y_pred_xsmall_multi_mlp = xsmall_multi_mlp.predict(abn_test_corr_dataset)
y_pred_xsmall_corr_multi_mlp = xsmall_corr_multi_mlp.predict(abn_test_corr_dataset)
y_pred_large_multi_mlp = large_multi_mlp.predict(abn_test_corr_dataset)
y_pred_large_corr_multi_mlp = large_corr_multi_mlp.predict(abn_test_corr_dataset)



abn_corr_SS_res_xsmall_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn_corr - y_pred_xsmall_multi_mlp),
                                                       axis=0).numpy()
abn_corr_R_xsmall_multi_mlp = 1 - abn_corr_SS_res_xsmall_multi_mlp/abn_corr_SS_total
abn_corr_R_xsmall_multi_mlp = pd.Series(abn_corr_R_xsmall_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small set')

abn_corr_SS_res_xsmall_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn_corr - y_pred_xsmall_corr_multi_mlp),
                                                  axis=0).numpy()
abn_corr_R_xsmall_corr_multi_mlp = 1 - abn_corr_SS_res_xsmall_corr_multi_mlp/abn_corr_SS_total
abn_corr_R_xsmall_corr_multi_mlp = pd.Series(abn_corr_R_xsmall_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on extra small correlated set')

abn_corr_SS_res_large_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn_corr - y_pred_large_multi_mlp),
                                                      axis=0).numpy()
abn_corr_R_large_multi_mlp = 1 - abn_corr_SS_res_large_multi_mlp/abn_corr_SS_total
abn_corr_R_large_multi_mlp = pd.Series(abn_corr_R_large_multi_mlp, index=metabolites,
                                         name='R' + chr(0x00B2) + ' muti-output MLP trained on large set')

abn_corr_SS_res_large_corr_multi_mlp = tf.reduce_mean(tf.math.square(y_val_abn_corr - y_pred_large_corr_multi_mlp),
                                                  axis=0).numpy()
abn_corr_R_large_corr_multi_mlp = 1 - abn_corr_SS_res_large_corr_multi_mlp/abn_corr_SS_total
abn_corr_R_large_corr_multi_mlp = pd.Series(abn_corr_R_large_corr_multi_mlp, index=metabolites,
                            name='R' + chr(0x00B2) + ' muti-output MLP trained on large correlated set')

# %% [markdown]
# ### XI.7.i Create the table

# %%
summary_table_abn_xsmall_corr = pd.concat([abn_corr_R_xsmall_multi_mlp,
                                           abn_corr_R_xsmall_corr_multi_mlp,
                                           abn_corr_SS_total], axis=1)

summary_table_abn_large_corr = pd.concat([abn_corr_R_large_multi_mlp,
                                          abn_corr_R_large_corr_multi_mlp,
                                          abn_corr_SS_total], axis=1)

# %%
summary_table_abn_xsmall_corr.style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col7,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col7,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row2_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row2_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row2_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row2_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row2_col7,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col7,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row5_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row5_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row5_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row7_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row7_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row7_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row10_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row11_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row11_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row11_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row11_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row11_col7,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row12_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row12_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row12_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row13_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row14_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row14_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row15_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row15_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row15_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row18_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row19_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row19_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row19_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row19_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row19_col7,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row22_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row22_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row22_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row25_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row25_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row25_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row25_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row25_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row27_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row27_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row27_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row27_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row30_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row32_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row33_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row33_col2,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row33_col3,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row33_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row33_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row33_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row35_col6,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c ...
#             background-color:  lightgreen;
#             font-weight:  ;
#         }#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row2_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row5_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row6_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row7_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row8_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row10_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row11_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row12_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row13_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row14_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row15_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row16_col0,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row17_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row18_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row19_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row20_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row22_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row24_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row25_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row27_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row29_col4,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row30_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row32_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row33_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row35_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row37_col1,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row38_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row40_col7,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row44_col5,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row45_col1{
#             background-color:  lightgreen;
#             font-weight:  bold;
#         }#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row0_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row1_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row2_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row3_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row4_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row5_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row6_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row7_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row8_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row9_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row10_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row11_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row12_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row13_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row14_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row15_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row16_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row17_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row18_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row19_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row20_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row21_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row22_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row23_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row24_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row25_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row26_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row27_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row28_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row29_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row30_col8,#T_ce79e6ec_df21_11eb_b65b_9bc947eb92c5row31_col8,#T_ce79e6ec_df2

# %%
summary_table_abn_large_corr.style.apply(color_traget, axis=1).apply(font_min_RMSE, axis=1)
# Out:
# <style  type="text/css" >
# #T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row0_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row0_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row0_col3,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row0_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row0_col5,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row0_col6,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row0_col7,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row1_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row1_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row1_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row1_col3,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row1_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row1_col6,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row1_col7,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row2_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row2_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row2_col3,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row2_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row2_col5,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row2_col6,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row2_col7,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row3_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row3_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row3_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row3_col3,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row3_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row3_col6,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row4_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row4_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row4_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row4_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row4_col6,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row5_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row5_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row5_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row6_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row6_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row6_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row7_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row7_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row7_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row8_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row8_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row8_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row9_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row9_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row9_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row10_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row10_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row10_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row11_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row11_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row11_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row11_col3,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row11_col5,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row11_col6,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row11_col7,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row12_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row12_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row12_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row13_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row13_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row14_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row14_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row15_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row15_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row15_col5,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row15_col7,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row16_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row16_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row16_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row17_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row17_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row17_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row18_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row18_col4,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row18_col5,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row19_col0,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row19_col1,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row19_col2,#T_ce79e6ee_df21_11eb_b65b_9bc947eb92c5row19_co ...

# %% [markdown]
# # Interprete MLP

# %%
def saliency_map_multi(model, spectrum):
    """
    This function should compute the saliency map as described above.
    It should return the tuple (saliency_map, decoded_predictions).
    """
    with tf.GradientTape(persistent=True) as tape:
        tape.watch(spectrum)
        preds = model(spectrum[tf.newaxis, ...])
        preds = tf.squeeze(preds)
        metabolites = [preds[i] for i in range(48)]
    sms = []
    for i in range(48):
        grads = tape.gradient(metabolites[i], spectrum)
        sms.append(tf.math.abs(grads))
    return sms, preds

def saliency_map_single(models, spectrum):
    """
    This function should compute the saliency map as described above.
    It should return the tuple (saliency_map, decoded_predictions).
    """
    sms = []
    for i in range(48):
        model = models[i]
        with tf.GradientTape() as tape:
            tape.watch(spectrum)
            preds = model(spectrum[tf.newaxis, ...])
            preds = tf.squeeze(preds)
        grads = tape.gradient(preds, spectrum)
        sms.append(tf.math.abs(grads))
    return sms, preds

# %%
df_spectrum_metabolites = []
for i in range(4):
    filename_spectrum_metabolite = '../data/Metabolite_spectrum/metabolite_{}.txt'.format(i)
    data_spectrum_metabolite = np.loadtxt(filename_spectrum_metabolite, dtype=float)
    df_spectrum_metabolites.append(pd.DataFrame(data_spectrum_metabolite))
for i in range(45, 47):
    filename_spectrum_metabolite = '../data/Metabolite_spectrum/metabolite_{}.txt'.format(i)
    data_spectrum_metabolite = np.loadtxt(filename_spectrum_metabolite, dtype=float)
    df_spectrum_metabolites.append(pd.DataFrame(data_spectrum_metabolite))

# %%
# Compute the saliency map for a randomly selected image
for parsed_record in test_dataset.shuffle(1000).take(1):
    random_spectrum = parsed_record[0][0]
    true_concentration = parsed_record[1][0].numpy()
    sms, pred_concentration = saliency_map_multi(large_multi_mlp, random_spectrum)


fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(sms[2] * 300)
axs[0, 0].plot(random_spectrum * 20000, color='orange')
axs[0, 0].plot(df_spectrum_metabolites[2], color='red')
axs[0, 0].set_title("Citric acid")
axs[1, 0].plot(sms[1] * 300)
axs[1, 0].plot(random_spectrum * 20000, color='orange')
axs[1, 0].plot(df_spectrum_metabolites[1], color='red')
axs[1, 0].set_title("Hippuric acid")
axs[0, 1].plot(random_spectrum * 20000, color='orange')
axs[0, 1].plot(df_spectrum_metabolites[4] * 4000, color='red')
axs[0, 1].plot(sms[45] * 300)
axs[0, 1].set_title("Deoxyadenosine")
axs[1, 1].plot(random_spectrum * 20000, color='orange')
axs[1, 1].plot(df_spectrum_metabolites[5] * 10000, color='red')
axs[1, 1].plot(sms[46] * 300)
axs[1, 1].set_title("Butyric")
fig.tight_layout()
fig.set_size_inches(18.5, 10.5)
# plt.figure(figsize=(12, 5))
# plt.plot(sms[46] * 500)
# plt.plot(random_spectrum * 20000, color='yellow')
# plt.plot(df_spectrum_creatinine, color='red')
# plt.title("Saliency map of metabolite {}".format(0))



plt.show()

# print("Model predictions:\n{}".format(decoded_preds))

# %%
# Compute the saliency map for a randomly selected image
for parsed_record in test_dataset.shuffle(1000).take(1):
    random_spectrum = parsed_record[0][0]
    true_concentration = parsed_record[1][0].numpy()
    sms, pred_concentration = saliency_map_single(xsmall_inde_mlps, random_spectrum)



fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(sms[2] * 500)
axs[0, 0].plot(random_spectrum * 20000, color='orange')
axs[0, 0].plot(df_spectrum_metabolites[2], color='red')
axs[0, 0].set_title("Citric acid")
axs[1, 0].plot(sms[1] * 500)
axs[1, 0].plot(random_spectrum * 20000, color='orange')
axs[1, 0].plot(df_spectrum_metabolites[1], color='red')
axs[1, 0].set_title("Hippuric acid")
axs[0, 1].plot(random_spectrum * 20, color='orange')
axs[0, 1].plot(df_spectrum_metabolites[4] * 3, color='red')
axs[0, 1].plot(sms[45] * 10)
axs[0, 1].set_title("Deoxyadenosine")
axs[1, 1].plot(random_spectrum * 20, color='orange')
axs[1, 1].plot(df_spectrum_metabolites[5] * 30, color='red')
axs[1, 1].plot(sms[46])
axs[1, 1].set_title("Butyric")
fig.tight_layout()
fig.set_size_inches(18.5, 10.5)
# plt.figure(figsize=(12, 5))
# plt.plot(sms[46] * 500)
# plt.plot(random_spectrum * 20000, color='yellow')
# plt.plot(df_spectrum_creatinine, color='red')
# plt.title("Saliency map of metabolite {}".format(0))



plt.show()

# print("Model predictions:\n{}".format(decoded_preds))
